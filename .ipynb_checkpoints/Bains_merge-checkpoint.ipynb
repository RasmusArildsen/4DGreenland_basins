# %%
# run_monte_carlo.py
from pathlib import Path

from mc_postprocess_2 import (
    build_mc_products,   # optional at end
    make_perturbed_dem,
    make_perturbed_bed,
)

import basin_core as bc
from basin_core import (
    setup_grass_env,
    start_grass_from_raster,
    prepare_dem_and_mask,
    ensure_grass_addon,
    run_hydro_for_dem,
    build_hybrid_dem_for_run_mask,   
    import_dem_native,
    QGIS_PREFIX_DEFAULT,
)


# --------------------------------------------------------------------
# USER SETTINGS
# --------------------------------------------------------------------
dem_res = 100
dem_type = "hybrid"  # 'surf' | 'bed' | 'hybrid'

if dem_res == 500:
    DEM = r"/Users/ralor/Rasmus/DTU/Cryo/DEM/arcticDEM_500m_ice_sheet.tif"
    VAR = r"/Users/ralor/Rasmus/DTU/Cryo/DEM/arcticdem_mosaic_500m_v4.1/arcticdem_mosaic_500m_v4.1_sigma_ice_masked.tif"
    fill_name = "dem_filled_500m"
    STREAM_THRESHOLD = 200
    CORR_PIX = 5

    if dem_type == "surf":
        OUT = r"/Volumes/Lenovo PS8/4DBasins/arcticdem500_mc"
    elif dem_type == "bed":
        OUT = r"/Volumes/Lenovo PS8/4DBasins/bed_machine_500_mc"
    else:
        OUT = r"/Volumes/Lenovo PS8/4DBasins/hybrid_500_mc"

elif dem_res == 100:
    DEM = r"/Users/ralor/Rasmus/DTU/Cryo/DEM/arcticDEM_100m/arcticdem_mosaic_100m_v4.1_dem_clipped.tif"
    VAR = r"/Users/ralor/Rasmus/DTU/Cryo/DEM/arcticDEM_100m/arcticdem_mosaic_100m_v4.1_sigma_ice_masked.tif"
    fill_name = r"dem_filled_100m"
    STREAM_THRESHOLD = 5000
    CORR_PIX = 5

    if dem_type == "surf":
        OUT = r"/Volumes/Lenovo PS8/4DBasins/arcticdem100_mc"
    elif dem_type == "bed":
        OUT = r"/Volumes/Lenovo PS8/4DBasins/bed_machine_100_mc"
    else:
        OUT = r"/Volumes/Lenovo PS8/4DBasins/hybrid_100_mc"

else:
    raise ValueError("dem_res must be 100 or 500")

BASIN_PATTERN = "basins_hydro_mc_*.tif"
ICE_MASK = r"/Users/ralor/Rasmus/DTU/Jupyter_Notebook/4DGreenland_basins/data/ice_mask/02-PROMICE-2022-IceMask-polygon.gpkg"

N_MC = 500
START_I = 1

FILL_HOLES = False
FILL_METHOD = "bilinear"

# hydrology smoothing in run_hydro_for_dem (NOT used for hybrid; hybrid does its own smoothing)
SMOOTH = False
SMOOTH_SIZE = 3

QGIS_PREFIX = QGIS_PREFIX_DEFAULT

# Hybrid inputs (boundary between surface-use and bed-use)
POLY_2000M = r"/Volumes/Lenovo PS8/4DBasins/til_rasmus/til_rasmus_ensemble/2000m_isoline.shp"
if dem_res == 500:
    BED_FILE   = r"/Volumes/Lenovo PS8/4DBasins/til_rasmus/til_rasmus_ensemble/bedmachine_500m.tif"
    BED_ERR    = r"/Volumes/Lenovo PS8/4DBasins/til_rasmus/til_rasmus_ensemble/err_bed_500m.tif"
    BED_ERR_IS_VARIANCE = False  # True if bed_err is σ²

if dem_res == 100:
    BED_FILE   = r"/Volumes/Lenovo PS8/4DBasins/til_rasmus/til_rasmus_ensemble/bedmachine_100m.tif"
    BED_ERR    = r"/Volumes/Lenovo PS8/4DBasins/til_rasmus/til_rasmus_ensemble/bedmachine_errbed_100m.tif"
    BED_ERR_IS_VARIANCE = False  # True if bed_err is σ²

# Optional exports per run
EXPORT_DEBUG = True
EXPORT_RUNS  = {11,30,31}     # set None to export all, or e.g. {11,12,50}
EXPORT_EVERY = 25       # only used if EXPORT_RUNS is None

Path(OUT).mkdir(parents=True, exist_ok=True)

# --------------------------------------------------------------------
# INIT GRASS
# --------------------------------------------------------------------
setup_grass_env(QGIS_PREFIX)
gs = bc.gs  # GRASS module initialised by setup_grass_env

MAPSET = f"MC_WORK_{dem_res}m"
GISDBASE, LOCATION, MAPSET = start_grass_from_raster(DEM, location="dem_loc", mapset=MAPSET)

ensure_grass_addon("r.stream.extract")
ensure_grass_addon("r.stream.basins")

# Create & switch to a work mapset so PERMANENT stays clean
gs.run_command("g.mapset", flags="c", mapset=MAPSET)

# --------------------------------------------------------------------
# HELPERS FOR CLEANUP + EXPORTS
# --------------------------------------------------------------------
def list_maps(map_type: str) -> set[str]:
    txt = gs.read_command("g.list", type=map_type, separator="newline")
    return {ln.strip() for ln in txt.splitlines() if ln.strip()}

def remove_maps(map_type: str, names: list[str]):
    if not names:
        return
    gs.run_command("g.remove", flags="f", type=map_type, name=",".join(names))

def raster_exists(name: str) -> bool:
    txt = gs.read_command("g.findfile", element="cell", file=name)
    return ("name=" in txt) and not ("name=\n" in txt or "name=\r\n" in txt)

def export_raster(name: str, out_path: Path, *, gdal_type: str | None = None, nodata=None):
    out_path.parent.mkdir(parents=True, exist_ok=True)

    # Remove color tables to avoid SetColorTable warnings for Int32 exports
    try:
        gs.run_command("r.colors", flags="r", map=name)
    except Exception:
        pass

    kwargs = dict(
        input=name,
        output=out_path.as_posix(),
        format="GTiff",
        createopt="COMPRESS=LZW,TILED=YES,BIGTIFF=YES",
        overwrite=True,
        flags="f",  # <-- override precision-loss abort
    )
    if gdal_type is not None:
        kwargs["type"] = gdal_type
    if nodata is not None:
        kwargs["nodata"] = nodata

    gs.run_command("r.out.gdal", **kwargs)

def export_maps_for_run(i: int, out_dir: str):
    out_dir = Path(out_dir)
    tag_h = f"_mc_{i:03d}"   # hydrology names inside run_hydro_pipeline
    tag   = f"_{i:03d}"      # hybrid names inside build_hybrid_dem_for_run

    exports = [
        # hydrology products
        (f"accum{tag_h}",    out_dir / f"accum_hybrid{tag_h}.tif",    None),
        (f"flow_dir{tag_h}", out_dir / f"flowdir_hybrid{tag_h}.tif",  "Int32"),
        (f"streams{tag_h}",  out_dir / f"streams_hybrid{tag_h}.tif",  "Int16"),
        (f"basins{tag_h}",   out_dir / f"basins_hybrid{tag_h}.tif",   "Int32"),

        # hybrid intermediates
        (f"hybrid_dem{tag}",     out_dir / f"hybrid_dem{tag}.tif",     "Float64"),
        (f"bed_masked{tag}",     out_dir / f"bed_masked{tag}.tif",     "Float64"),
        (f"surface_masked{tag}", out_dir / f"surface_masked{tag}.tif", "Float64"),
        (f"dem_filledA{tag}",    out_dir / f"dem_filledA{tag}.tif",    "Float64"),
        (f"dem_filledB{tag}",    out_dir / f"dem_filledB{tag}.tif",    "Float64"),
    ]

    for name, fn, gtype in exports:
        if not raster_exists(name):
            print(f"⚠️ Missing raster (skip): {name}")
            continue
        export_raster(name, fn, gdal_type=gtype, nodata=-9999)
        print(f"📤 Exported {name} → {fn}")

# --------------------------------------------------------------------
# DEM + MASK
# --------------------------------------------------------------------
dem_map, ice_mask_rast = prepare_dem_and_mask(
    dem_path=DEM,
    ice_mask_path=ICE_MASK,
    fill_holes=FILL_HOLES,
    fill_method=FILL_METHOD,
    filled_name=fill_name,
)

# variance for surface perturbation
import_dem_native(VAR, out_name="dem_var")

# --------------------------------------------------------------------
# IMPORT HYBRID ANCILLARIES ONCE (IN CURRENT MAPSET)
# --------------------------------------------------------------------
SURF_2000 = r"/Users/ralor/Rasmus/DTU/Cryo/DEM/arcticDEM_500m_ice_sheet_2000m.tif"

# Bed + bed error (for perturbations)
import_dem_native(BED_FILE, out_name="bed_raster")
import_dem_native(BED_ERR,  out_name="bed_err")

# 2000m mask raster (values >=2000, NULL below)
import_dem_native(SURF_2000, out_name="surf_mask_2000")   # <-- THIS NAME is used later


POLY_VEC = "switch_2000m"
gs.run_command("v.import", input=POLY_2000M.replace("\\", "/"), output=POLY_VEC, overwrite=True)

# --------------------------------------------------------------------
# KEEP SETS (for cleanup)
# --------------------------------------------------------------------

KEEP_RASTERS = {
    dem_map, "dem_var", ice_mask_rast, fill_name, "MASK",
    "bed_raster", "bed_err", "surf_mask_2000"
}

# prepare_dem_and_mask creates ice_mask_vec
KEEP_VECTORS = {"ice_mask_vec"}
# Out:
# ✅ GISBASE: /Applications/GRASS-8.4.app/Contents/Resources
# ✅ grass_python: /Applications/GRASS-8.4.app/Contents/Resources/etc/python
# 🌿 GRASS session initialized in:
#    /Users/ralor/Documents/grassdata/dem_loc/MC_WORK_100m
#
# GISDBASE='/Users/ralor/Documents/grassdata';
# LOCATION_NAME='dem_loc';
# MAPSET='MC_WORK_100m';
#
# ✓ r.stream.extract at True
# ✓ r.stream.basins at True
# WARNING: <MC_WORK_100m> is already the current mapset
# Raster MASK removed
# WARNING: Raster map <dem> already exists and will be overwritten
# Over-riding projection check
# Importing raster map <dem>...
# ✓ r.in.gdal → dem
# projection: 99 (WGS 84 / NSIDC Sea Ice Polar Stereographic North)
# zone:       0
# datum:      wgs84
# ellipsoid:  wgs84
# north:      -790000
# south:      -3308300
# west:       -619900
# east:       837000
# nsres:      100
# ewres:      100
# rows:       25183
# cols:       14569
# cells:      366891127
# → Importing vector ice mask from: /Users/ralor/Rasmus/DTU/Jupyter_Notebook/4DGreenland_basins/data/ice_mask/02-PROMICE-2022-IceMask-polygon.gpkg
# Check if OGR layer <02-PROMICE-2022-IceMask-polygon> contains polygons...
#
# WARNING: Vector map <ice_mask_vec> already exists and will be overwritten
# Creating attribute table for layer <02-PROMICE-2022-IceMask-polygon>...
# WARNING: Name <02-PROMICE-2022-IceMask-polygon> is not SQL compliant. Must
#          start with a letter.
# Importing 1 features (OGR layer <02-PROMICE-2022-IceMask-polygon>)...
#
# -----------------------------------------------------
# Registering primitives...
# -----------------------------------------------------
# Cleaning polygons
# -----------------------------------------------------
# Breaking polygons...
# Breaking polygons (pass 1: select break points)...
#
# Breaking polygons (pass 2: break at selected points)...
#
# -----------------------------------------------------
# Removing duplicates...
#
# -----------------------------------------------------
# Breaking boundaries...
#
# -----------------------------------------------------
# Removing duplicates...
#
# -----------------------------------------------------
# Cleaning boundaries at nodes...
#
# -----------------------------------------------------
# Merging boundaries...
#
# -----------------------------------------------------
# Removing dangles...
#
# -----------------------------------------------------
# Building areas...
#
# -----------------------------------------------------
# Removing bridges...
#
# -----------------------------------------------------
# Registering primitives...
# Building areas...
#
# Attaching islands...
#
# -----------------------------------------------------
# Finding centroids for OGR layer <02-PROMICE-2022-IceMask-polygon>...
#
# -----------------------------------------------------
# Writing centroids...
#
# -----------------------------------------------------
# 1 input polygons
# Total area: 1.72481E+12 (1 areas)
# -----------------------------------------------------
# Copying features...
#
# Building topology for vector map <ice_mask_vec@MC_WORK_100m>...
# Registering primitives...
# Building areas...
#
# Attaching islands...
#
# Attaching centroids...
#
# Input
# </Users/ralor/Rasmus/DTU/Jupyter_Notebook/4DGreenland_basins/data/ice_mask/02-PROMICE-2022-IceMask-polygon.gpkg>
# successfully imported without reprojection
# Pass 1 of 6:
# Reading areas...
#
# Writing raster map...
# ✓ Ice mask imported with v.import → ice_mask_vec
# Pass 2 of 6:
# Reading areas...
#
# Writing raster map...
#
# Pass 3 of 6:
# Reading areas...
#
# Writing raster map...
#
# Pass 4 of 6:
# Reading areas...
#
# Writing raster map...
#
# Pass 5 of 6:
# Reading areas...
#
# Writing raster map...
#
# Pass 6 of 6:
# Reading areas...
#
# Writing raster map...
#
# v.to.rast complete.
# ✓ Ice mask rasterized → ice_mask_rast
# ✓ Mask set from ice mask
# All subsequent raster operations will be limited to the MASK area. Removing
# or renaming raster map named 'MASK' will restore raster operations to
# normal.
# WARNING: Raster map <dem_var> already exists and will be overwritten
# Over-riding projection check
# Importing raster map <dem_var>...
#
# WARNING: Raster map <bed_raster> already exists and will be overwritten
# Over-riding projection check
# Importing raster map <bed_raster>...
# ✓ r.in.gdal → dem_var
# ✓ r.in.gdal → bed_raster
# WARNING: Raster map <bed_err> already exists and will be overwritten
# Over-riding projection check
# Importing raster map <bed_err>...
# ✓ r.in.gdal → bed_err
# WARNING: Raster map <surf_mask_2000> already exists and will be overwritten
# Over-riding projection check
# Importing raster map <surf_mask_2000>...
#
# Check if OGR layer <2000m_isoline> contains polygons...
#
# WARNING: Vector map <switch_2000m> already exists and will be overwritten
# Creating attribute table for layer <2000m_isoline>...
# WARNING: Name <2000m_isoline> is not SQL compliant. Must start with a
#          letter.
# Importing 358 features (OGR layer <2000m_isoline>)...
# ✓ r.in.gdal → surf_mask_2000
# -----------------------------------------------------
# Building topology for vector map <switch_2000m@MC_WORK_100m>...
# Registering primitives...
# Input </Volumes/Lenovo
# PS8/4DBasins/til_rasmus/til_rasmus_ensemble/2000m_isoline.shp> successfully
# imported without reprojection

# %%
# --------------------------------------------------------------------
# MONTE CARLO LOOP
# --------------------------------------------------------------------
for i in range(START_I, N_MC + 1):
    print(f"\n==================== Monte Carlo Run {i:03d}/{N_MC} ====================")

    ras_before = list_maps("raster")
    vec_before = list_maps("vector")

    # 1) Perturbed surface DEM
    dem_mc = make_perturbed_dem(
        run_idx=i,
        base_dem=dem_map,
        var_map="dem_var",
        corr_pix=CORR_PIX,
    )

    # 2) Perturbed bed DEM
    bed_mc, pert_bed = make_perturbed_bed(
        run_idx=i,
        base_bed="bed_raster",
        err_map="bed_err",
        corr_pix=CORR_PIX,
        err_is_variance=BED_ERR_IS_VARIANCE,
    )

    # 3) Decide which DEM to run hydrology on
    if dem_type == "surf":
        dem_for_hydro = dem_mc
    elif dem_type == "bed":
        dem_for_hydro = bed_mc
    else:
        tag = f"_{i:03d}"
        dem_for_hydro = build_hybrid_dem_for_run_mask(
            surface_dem=dem_mc,
            bed_raster=bed_mc,
            inside_mask_raster="surf_mask_2000",   # <-- now exists
            tag=f"_{i:03d}",
            smooth_size=3,
        )

    # 4) Hydrology
    run_hydro_for_dem(
        dem_name=dem_for_hydro,
        out_dir=OUT,
        stream_threshold=STREAM_THRESHOLD,
        run_idx=i,
        smooth=False,
        perturbation_map=f"pert_mc_{i:03d}",
    )

    # 5) Optional exports (BEFORE cleanup)
    if EXPORT_DEBUG:
        if EXPORT_RUNS is not None:
            do_export = i in EXPORT_RUNS
        else:
            do_export = (i % EXPORT_EVERY == 0)

        if do_export:
            export_maps_for_run(i, OUT)

    # 6) Cleanup: remove anything created in this iteration (except the base maps)
    ras_after = list_maps("raster")
    vec_after = list_maps("vector")

    new_rasters = sorted((ras_after - ras_before) - KEEP_RASTERS)
    new_vectors = sorted((vec_after - vec_before) - KEEP_VECTORS)

    remove_maps("raster", new_rasters)
    remove_maps("vector", new_vectors)

# Optional postprocess:
# build_mc_products(OUT, basin_pattern=BASIN_PATTERN, chunk_rows=32)
# Out:
# Raster MASK removed
# ==================== Monte Carlo Run 001/500 ====================
# ✓ Created perturbation: pert_mc_001
# ✓ Created perturbed DEM: dem_mc_001
# ERROR: No existing MASK to remove
#
#
# ERROR: No existing MASK to remove
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 14613 unresolved areas
# Repeat to get the final directions...
# Found 650 unresolved areas
# Writing output raster maps...
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 75098 unresolved areas
# Repeat to get the final directions...
# Found 6252 unresolved areas
# Writing output raster maps...
# projection: 99 (WGS 84 / NSIDC Sea Ice Polar Stereographic North)
# zone:       0
# datum:      wgs84
# ellipsoid:  wgs84
# north:      -790000
# south:      -3308300
# west:       -619900
# east:       837000
# nsres:      100
# ewres:      100
# rows:       25183
# cols:       14569
# cells:      366891127
# ✓ Mask set from ice_mask_rast
# 🔧 Running r.watershed on hybrid_dem_001
# All subsequent raster operations will be limited to the MASK area. Removing
# or renaming raster map named 'MASK' will restore raster operations to
# normal.
# SECTION 1 beginning: Initiating Variables. 4 sections total.
# SECTION 1a: Mark masked and NULL cells
#
# SECTION 1b: Determining Offmap Flow.
#
# SECTION 2: A* Search.
#
# SECTION 3a: Accumulating Surface Flow with MFD.
#
# SECTION 3b: Adjusting drainage directions.
# SECTION 4: Closing Maps.
# Closing accumulation map
#
# Closing flow direction map
# ✓ r.watershed completed
# Loading input raster maps...
#
# Initializing A* search...
#
# A* Search...
#
# Extracting streams...
#
# Thinning stream segments...
#
# Writing output raster maps...
#
# Memory swap calculation (may take some time)...
# Reading raster map <flow_dir_mc_001>...
#
# Calculating basins using streams...
# Reading raster map <streams_mc_001>...
#
# Finding nodes...
#
# Delineating basins for 677 outlets...
#
# Writing raster map <basins_mc_001>...
# ✓ r.stream.basins completed
# 📤 Exporting hybrid_dem_001 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_001.tif
# ❌ Failed to export hybrid_dem_001: Module run `r.out.gdal --o input=hybrid_dem_001 output=/Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_001.tif format=GTiff type=Float32 createopt=COMPRESS=LZW,TILED=YES,BIGTIFF=YES nodata=-9999` ended with an error.
# The subprocess ended with a non-zero return code: 1. See errors above the traceback or in the error output.
# 📤 Exporting flow_dir_mc_001 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_001.tif
# WARNING: Precision loss: Float32 can not preserve the DCELL precision of
#          raster <hybrid_dem_001>. This can be avoided by using Float64
# ERROR: Raster export aborted. To override data loss check, use the -f flag
# Checking GDAL data type and nodata value...
#
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: flowdir_hydro_mc_001.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_001.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting streams_mc_001 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_001.tif
# Using GDAL data type <Int16>
# Exporting raster data to GTiff format...
# ERROR 6: streams_hydro_mc_001.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_001.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting basins_mc_001 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_001.tif
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: basins_hydro_mc_001.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_001.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting pert_mc_001 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/perturbation_mc_001.tif
# Using GDAL data type <Float64>
# Input raster map contains cells with NULL-value (no-data). The value nan
# will be used to represent no-data values in the input map. You can specify
# a nodata value with the nodata option.
# Exporting raster data to GTiff format...
# ERROR 6: perturbation_mc_001.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/perturbation_mc_001.tif> created.
# Raster MASK removed
# ✅ Finished hydrology for DEM 'hybrid_dem_001' (tag='_mc_001')
# Removing raster <accum_mc_001>
# Removing raster <basins_mc_001>
# Removing raster <bed_dem_001>
# Removing raster <bed_masked_001>
# Removing raster <bed_mc_001>
# Removing raster <dem_filledA_001>
# Removing raster <dem_filledB_001>
# Removing raster <dem_mc_001>
# Removing raster <flow_dirA_001>
# Removing raster <flow_dirB_001>
# Removing raster <flow_dir_mc_001>
# Removing raster <hybrid_dem_001>
# Removing raster <inside_mask_001>
# Removing raster <noise_corr_bed_001>
# Removing raster <noise_raw_bed_001>
# Removing raster <outside_mask_001>
# Removing raster <pert_bed_001>
# Removing raster <pert_mc_001>
# Removing raster <streams_mc_001>
# Removing raster <surface_dem_smooth_001>
# Removing raster <surface_masked_001>
# ==================== Monte Carlo Run 002/500 ====================
# ERROR: No existing MASK to remove
# ✓ Created perturbation: pert_mc_002
# ✓ Created perturbed DEM: dem_mc_002
# ERROR: No existing MASK to remove
#
#
# ERROR: No existing MASK to remove
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 14572 unresolved areas
# Repeat to get the final directions...
# Found 617 unresolved areas
# Writing output raster maps...
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 75098 unresolved areas
# Repeat to get the final directions...
# Found 6138 unresolved areas
# Writing output raster maps...
# projection: 99 (WGS 84 / NSIDC Sea Ice Polar Stereographic North)
# zone:       0
# datum:      wgs84
# ellipsoid:  wgs84
# north:      -790000
# south:      -3308300
# west:       -619900
# east:       837000
# nsres:      100
# ewres:      100
# rows:       25183
# cols:       14569
# cells:      366891127
# ✓ Mask set from ice_mask_rast
# 🔧 Running r.watershed on hybrid_dem_002
# All subsequent raster operations will be limited to the MASK area. Removing
# or renaming raster map named 'MASK' will restore raster operations to
# normal.
# SECTION 1 beginning: Initiating Variables. 4 sections total.
# SECTION 1a: Mark masked and NULL cells
#
# SECTION 1b: Determining Offmap Flow.
#
# SECTION 2: A* Search.
#
# SECTION 3a: Accumulating Surface Flow with MFD.
#
# SECTION 3b: Adjusting drainage directions.
# SECTION 4: Closing Maps.
# Closing accumulation map
#
# Closing flow direction map
# ✓ r.watershed completed
# Loading input raster maps...
#
# Initializing A* search...
#
# A* Search...
#
# Extracting streams...
#
# Thinning stream segments...
#
# Writing output raster maps...
#
# Memory swap calculation (may take some time)...
# Reading raster map <flow_dir_mc_002>...
#
# Calculating basins using streams...
# Reading raster map <streams_mc_002>...
#
# Finding nodes...
#
# Delineating basins for 682 outlets...
#
# Writing raster map <basins_mc_002>...
# ✓ r.stream.basins completed
# 📤 Exporting hybrid_dem_002 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_002.tif
# ❌ Failed to export hybrid_dem_002: Module run `r.out.gdal --o input=hybrid_dem_002 output=/Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_002.tif format=GTiff type=Float32 createopt=COMPRESS=LZW,TILED=YES,BIGTIFF=YES nodata=-9999` ended with an error.
# The subprocess ended with a non-zero return code: 1. See errors above the traceback or in the error output.
# 📤 Exporting flow_dir_mc_002 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_002.tif
# WARNING: Precision loss: Float32 can not preserve the DCELL precision of
#          raster <hybrid_dem_002>. This can be avoided by using Float64
# ERROR: Raster export aborted. To override data loss check, use the -f flag
# Checking GDAL data type and nodata value...
#
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: flowdir_hydro_mc_002.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_002.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting streams_mc_002 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_002.tif
# Using GDAL data type <Int16>
# Exporting raster data to GTiff format...
# ERROR 6: streams_hydro_mc_002.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_002.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting basins_mc_002 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_002.tif
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: basins_hydro_mc_002.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_002.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting pert_mc_002 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/perturbation_mc_002.tif
# Using GDAL data type <Float64>
# Input raster map contains cells with NULL-value (no-data). The value nan
# will be used to represent no-data values in the input map. You can specify
# a nodata value with the nodata option.
# Exporting raster data to GTiff format...
# ERROR 6: perturbation_mc_002.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/perturbation_mc_002.tif> created.
# Raster MASK removed
# ✅ Finished hydrology for DEM 'hybrid_dem_002' (tag='_mc_002')
# Removing raster <accum_mc_002>
# Removing raster <basins_mc_002>
# Removing raster <bed_dem_002>
# Removing raster <bed_masked_002>
# Removing raster <bed_mc_002>
# Removing raster <dem_filledA_002>
# Removing raster <dem_filledB_002>
# Removing raster <dem_mc_002>
# Removing raster <flow_dirA_002>
# Removing raster <flow_dirB_002>
# Removing raster <flow_dir_mc_002>
# Removing raster <hybrid_dem_002>
# Removing raster <inside_mask_002>
# Removing raster <noise_corr_bed_002>
# Removing raster <noise_raw_bed_002>
# Removing raster <outside_mask_002>
# Removing raster <pert_bed_002>
# Removing raster <pert_mc_002>
# Removing raster <streams_mc_002>
# Removing raster <surface_dem_smooth_002>
# Removing raster <surface_masked_002>
# ERROR: No existing MASK to remove
# ==================== Monte Carlo Run 003/500 ====================
# ✓ Created perturbation: pert_mc_003
# ✓ Created perturbed DEM: dem_mc_003
# ERROR: No existing MASK to remove
#
#
# ERROR: No existing MASK to remove
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 14601 unresolved areas
# Repeat to get the final directions...
# Found 632 unresolved areas
# Writing output raster maps...
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 75349 unresolved areas
# Repeat to get the final directions...
# Found 6155 unresolved areas
# Writing output raster maps...
# projection: 99 (WGS 84 / NSIDC Sea Ice Polar Stereographic North)
# zone:       0
# datum:      wgs84
# ellipsoid:  wgs84
# north:      -790000
# south:      -3308300
# west:       -619900
# east:       837000
# nsres:      100
# ewres:      100
# rows:       25183
# cols:       14569
# cells:      366891127
# ✓ Mask set from ice_mask_rast
# 🔧 Running r.watershed on hybrid_dem_003
# All subsequent raster operations will be limited to the MASK area. Removing
# or renaming raster map named 'MASK' will restore raster operations to
# normal.
# SECTION 1 beginning: Initiating Variables. 4 sections total.
# SECTION 1a: Mark masked and NULL cells
#
# SECTION 1b: Determining Offmap Flow.
#
# SECTION 2: A* Search.
#
# SECTION 3a: Accumulating Surface Flow with MFD.
#
# SECTION 3b: Adjusting drainage directions.
# SECTION 4: Closing Maps.
# Closing accumulation map
#
# Closing flow direction map
# ✓ r.watershed completed
# Loading input raster maps...
#
# Initializing A* search...
#
# A* Search...
#
# Extracting streams...
#
# Thinning stream segments...
#
# Writing output raster maps...
#
# Memory swap calculation (may take some time)...
# Reading raster map <flow_dir_mc_003>...
#
# Calculating basins using streams...
# Reading raster map <streams_mc_003>...
#
# Finding nodes...
#
# Delineating basins for 675 outlets...
#
# Writing raster map <basins_mc_003>...
# ✓ r.stream.basins completed
# 📤 Exporting hybrid_dem_003 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_003.tif
# ❌ Failed to export hybrid_dem_003: Module run `r.out.gdal --o input=hybrid_dem_003 output=/Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_003.tif format=GTiff type=Float32 createopt=COMPRESS=LZW,TILED=YES,BIGTIFF=YES nodata=-9999` ended with an error.
# The subprocess ended with a non-zero return code: 1. See errors above the traceback or in the error output.
# 📤 Exporting flow_dir_mc_003 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_003.tif
# WARNING: Precision loss: Float32 can not preserve the DCELL precision of
#          raster <hybrid_dem_003>. This can be avoided by using Float64
# ERROR: Raster export aborted. To override data loss check, use the -f flag
# Checking GDAL data type and nodata value...
#
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: flowdir_hydro_mc_003.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_003.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting streams_mc_003 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_003.tif
# Using GDAL data type <Int16>
# Exporting raster data to GTiff format...
# ERROR 6: streams_hydro_mc_003.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_003.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting basins_mc_003 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_003.tif
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: basins_hydro_mc_003.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_003.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting pert_mc_003 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/perturbation_mc_003.tif
# Using GDAL data type <Float64>
# Input raster map contains cells with NULL-value (no-data). The value nan
# will be used to represent no-data values in the input map. You can specify
# a nodata value with the nodata option.
# Exporting raster data to GTiff format...
# ERROR 6: perturbation_mc_003.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/perturbation_mc_003.tif> created.
# Raster MASK removed
# Removing raster <accum_mc_003>
# Removing raster <basins_mc_003>
# Removing raster <bed_dem_003>
# Removing raster <bed_masked_003>
# Removing raster <bed_mc_003>
# Removing raster <dem_filledA_003>
# Removing raster <dem_filledB_003>
# Removing raster <dem_mc_003>
# Removing raster <flow_dirA_003>
# Removing raster <flow_dirB_003>
# Removing raster <flow_dir_mc_003>
# ✅ Finished hydrology for DEM 'hybrid_dem_003' (tag='_mc_003')
# Removing raster <hybrid_dem_003>
# Removing raster <inside_mask_003>
# Removing raster <noise_corr_bed_003>
# Removing raster <noise_raw_bed_003>
# Removing raster <outside_mask_003>
# Removing raster <pert_bed_003>
# Removing raster <pert_mc_003>
# Removing raster <streams_mc_003>
# Removing raster <surface_dem_smooth_003>
# Removing raster <surface_masked_003>
# ==================== Monte Carlo Run 004/500 ====================
# ERROR: No existing MASK to remove
# ✓ Created perturbation: pert_mc_004
# ✓ Created perturbed DEM: dem_mc_004
# ERROR: No existing MASK to remove
#
#
# ERROR: No existing MASK to remove
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 14564 unresolved areas
# Repeat to get the final directions...
# Found 600 unresolved areas
# Writing output raster maps...
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 74912 unresolved areas
# Repeat to get the final directions...
# Found 6127 unresolved areas
# Writing output raster maps...
# projection: 99 (WGS 84 / NSIDC Sea Ice Polar Stereographic North)
# zone:       0
# datum:      wgs84
# ellipsoid:  wgs84
# north:      -790000
# south:      -3308300
# west:       -619900
# east:       837000
# nsres:      100
# ewres:      100
# rows:       25183
# cols:       14569
# cells:      366891127
# All subsequent raster operations will be limited to the MASK area. Removing
# or renaming raster map named 'MASK' will restore raster operations to
# normal.
# SECTION 1 beginning: Initiating Variables. 4 sections total.
# SECTION 1a: Mark masked and NULL cells
# ✓ Mask set from ice_mask_rast
# 🔧 Running r.watershed on hybrid_dem_004
# SECTION 1b: Determining Offmap Flow.
#
# SECTION 2: A* Search.
#
# SECTION 3a: Accumulating Surface Flow with MFD.
#
# SECTION 3b: Adjusting drainage directions.
# SECTION 4: Closing Maps.
# Closing accumulation map
#
# Closing flow direction map
# ✓ r.watershed completed
# Loading input raster maps...
#
# Initializing A* search...
#
# A* Search...
#
# Extracting streams...
#
# Thinning stream segments...
#
# Writing output raster maps...
#
# Memory swap calculation (may take some time)...
# Reading raster map <flow_dir_mc_004>...
#
# Calculating basins using streams...
# Reading raster map <streams_mc_004>...
#
# Finding nodes...
#
# Delineating basins for 695 outlets...
#
# Writing raster map <basins_mc_004>...
# ✓ r.stream.basins completed
# 📤 Exporting hybrid_dem_004 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_004.tif
# ❌ Failed to export hybrid_dem_004: Module run `r.out.gdal --o input=hybrid_dem_004 output=/Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_004.tif format=GTiff type=Float32 createopt=COMPRESS=LZW,TILED=YES,BIGTIFF=YES nodata=-9999` ended with an error.
# The subprocess ended with a non-zero return code: 1. See errors above the traceback or in the error output.
# 📤 Exporting flow_dir_mc_004 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_004.tif
# WARNING: Precision loss: Float32 can not preserve the DCELL precision of
#          raster <hybrid_dem_004>. This can be avoided by using Float64
# ERROR: Raster export aborted. To override data loss check, use the -f flag
# Checking GDAL data type and nodata value...
#
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: flowdir_hydro_mc_004.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_004.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting streams_mc_004 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_004.tif
# Using GDAL data type <Int16>
# Exporting raster data to GTiff format...
# ERROR 6: streams_hydro_mc_004.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_004.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting basins_mc_004 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_004.tif
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: basins_hydro_mc_004.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_004.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting pert_mc_004 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/perturbation_mc_004.tif
# Using GDAL data type <Float64>
# Input raster map contains cells with NULL-value (no-data). The value nan
# will be used to represent no-data values in the input map. You can specify
# a nodata value with the nodata option.
# Exporting raster data to GTiff format...
# ERROR 6: perturbation_mc_004.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/perturbation_mc_004.tif> created.
# Raster MASK removed
# ✅ Finished hydrology for DEM 'hybrid_dem_004' (tag='_mc_004')
# Removing raster <accum_mc_004>
# Removing raster <basins_mc_004>
# Removing raster <bed_dem_004>
# Removing raster <bed_masked_004>
# Removing raster <bed_mc_004>
# Removing raster <dem_filledA_004>
# Removing raster <dem_filledB_004>
# Removing raster <dem_mc_004>
# Removing raster <flow_dirA_004>
# Removing raster <flow_dirB_004>
# Removing raster <flow_dir_mc_004>
# Removing raster <hybrid_dem_004>
# Removing raster <inside_mask_004>
# Removing raster <noise_corr_bed_004>
# Removing raster <noise_raw_bed_004>
# Removing raster <outside_mask_004>
# Removing raster <pert_bed_004>
# Removing raster <pert_mc_004>
# Removing raster <streams_mc_004>
# Removing raster <surface_dem_smooth_004>
# Removing raster <surface_masked_004>
# ERROR: No existing MASK to remove
# ==================== Monte Carlo Run 005/500 ====================
# ✓ Created perturbation: pert_mc_005
# ✓ Created perturbed DEM: dem_mc_005
# ERROR: No existing MASK to remove
#
#
# ERROR: No existing MASK to remove
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 14585 unresolved areas
# Repeat to get the final directions...
# Found 624 unresolved areas
# Writing output raster maps...
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 75066 unresolved areas
# Repeat to get the final directions...
# Found 6166 unresolved areas
# Writing output raster maps...
# projection: 99 (WGS 84 / NSIDC Sea Ice Polar Stereographic North)
# zone:       0
# datum:      wgs84
# ellipsoid:  wgs84
# north:      -790000
# south:      -3308300
# west:       -619900
# east:       837000
# nsres:      100
# ewres:      100
# rows:       25183
# cols:       14569
# cells:      366891127
# ✓ Mask set from ice_mask_rast
# 🔧 Running r.watershed on hybrid_dem_005
# All subsequent raster operations will be limited to the MASK area. Removing
# or renaming raster map named 'MASK' will restore raster operations to
# normal.
# SECTION 1 beginning: Initiating Variables. 4 sections total.
# SECTION 1a: Mark masked and NULL cells
#
# SECTION 1b: Determining Offmap Flow.
#
# SECTION 2: A* Search.
#
# SECTION 3a: Accumulating Surface Flow with MFD.
#
# SECTION 3b: Adjusting drainage directions.
# SECTION 4: Closing Maps.
# Closing accumulation map
#
# Closing flow direction map
# ✓ r.watershed completed
# Loading input raster maps...
#
# Initializing A* search...
#
# A* Search...
#
# Extracting streams...
#
# Thinning stream segments...
#
# Writing output raster maps...
#
# Memory swap calculation (may take some time)...
# Reading raster map <flow_dir_mc_005>...
#
# Calculating basins using streams...
# Reading raster map <streams_mc_005>...
#
# Finding nodes...
#
# Delineating basins for 686 outlets...
#
# Writing raster map <basins_mc_005>...
# ✓ r.stream.basins completed
# 📤 Exporting hybrid_dem_005 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_005.tif
# ❌ Failed to export hybrid_dem_005: Module run `r.out.gdal --o input=hybrid_dem_005 output=/Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_005.tif format=GTiff type=Float32 createopt=COMPRESS=LZW,TILED=YES,BIGTIFF=YES nodata=-9999` ended with an error.
# The subprocess ended with a non-zero return code: 1. See errors above the traceback or in the error output.
# 📤 Exporting flow_dir_mc_005 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_005.tif
# WARNING: Precision loss: Float32 can not preserve the DCELL precision of
#          raster <hybrid_dem_005>. This can be avoided by using Float64
# ERROR: Raster export aborted. To override data loss check, use the -f flag
# Checking GDAL data type and nodata value...
#
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: flowdir_hydro_mc_005.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_005.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting streams_mc_005 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_005.tif
# Using GDAL data type <Int16>
# Exporting raster data to GTiff format...
# ERROR 6: streams_hydro_mc_005.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_005.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting basins_mc_005 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_005.tif
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: basins_hydro_mc_005.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_005.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting pert_mc_005 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/perturbation_mc_005.tif
# Using GDAL data type <Float64>
# Input raster map contains cells with NULL-value (no-data). The value nan
# will be used to represent no-data values in the input map. You can specify
# a nodata value with the nodata option.
# Exporting raster data to GTiff format...
# ERROR 6: perturbation_mc_005.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/perturbation_mc_005.tif> created.
# Raster MASK removed
# ✅ Finished hydrology for DEM 'hybrid_dem_005' (tag='_mc_005')
# Removing raster <accum_mc_005>
# Removing raster <basins_mc_005>
# Removing raster <bed_dem_005>
# Removing raster <bed_masked_005>
# Removing raster <bed_mc_005>
# Removing raster <dem_filledA_005>
# Removing raster <dem_filledB_005>
# Removing raster <dem_mc_005>
# Removing raster <flow_dirA_005>
# Removing raster <flow_dirB_005>
# Removing raster <flow_dir_mc_005>
# Removing raster <hybrid_dem_005>
# Removing raster <inside_mask_005>
# Removing raster <noise_corr_bed_005>
# Removing raster <noise_raw_bed_005>
# Removing raster <outside_mask_005>
# Removing raster <pert_bed_005>
# Removing raster <pert_mc_005>
# Removing raster <streams_mc_005>
# Removing raster <surface_dem_smooth_005>
# Removing raster <surface_masked_005>
# ==================== Monte Carlo Run 006/500 ====================
# ERROR: No existing MASK to remove
# ✓ Created perturbation: pert_mc_006
# ✓ Created perturbed DEM: dem_mc_006
# ERROR: No existing MASK to remove
#
#
# ERROR: No existing MASK to remove
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 14595 unresolved areas
# Repeat to get the final directions...
# Found 597 unresolved areas
# Writing output raster maps...
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 75104 unresolved areas
# Repeat to get the final directions...
# Found 6245 unresolved areas
# Writing output raster maps...
# projection: 99 (WGS 84 / NSIDC Sea Ice Polar Stereographic North)
# zone:       0
# datum:      wgs84
# ellipsoid:  wgs84
# north:      -790000
# south:      -3308300
# west:       -619900
# east:       837000
# nsres:      100
# ewres:      100
# rows:       25183
# cols:       14569
# cells:      366891127
# ✓ Mask set from ice_mask_rast
# 🔧 Running r.watershed on hybrid_dem_006
# All subsequent raster operations will be limited to the MASK area. Removing
# or renaming raster map named 'MASK' will restore raster operations to
# normal.
# SECTION 1 beginning: Initiating Variables. 4 sections total.
# SECTION 1a: Mark masked and NULL cells
#
# SECTION 1b: Determining Offmap Flow.
#
# SECTION 2: A* Search.
#
# SECTION 3a: Accumulating Surface Flow with MFD.
#
# SECTION 3b: Adjusting drainage directions.
# SECTION 4: Closing Maps.
# Closing accumulation map
#
# Closing flow direction map
# ✓ r.watershed completed
# Loading input raster maps...
#
# Initializing A* search...
#
# A* Search...
#
# Extracting streams...
#
# Thinning stream segments...
#
# Writing output raster maps...
#
# Memory swap calculation (may take some time)...
# Reading raster map <flow_dir_mc_006>...
#
# Calculating basins using streams...
# Reading raster map <streams_mc_006>...
#
# Finding nodes...
#
# Delineating basins for 687 outlets...
#
# Writing raster map <basins_mc_006>...
# ✓ r.stream.basins completed
# 📤 Exporting hybrid_dem_006 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_006.tif
# ❌ Failed to export hybrid_dem_006: Module run `r.out.gdal --o input=hybrid_dem_006 output=/Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_006.tif format=GTiff type=Float32 createopt=COMPRESS=LZW,TILED=YES,BIGTIFF=YES nodata=-9999` ended with an error.
# The subprocess ended with a non-zero return code: 1. See errors above the traceback or in the error output.
# 📤 Exporting flow_dir_mc_006 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_006.tif
# WARNING: Precision loss: Float32 can not preserve the DCELL precision of
#          raster <hybrid_dem_006>. This can be avoided by using Float64
# ERROR: Raster export aborted. To override data loss check, use the -f flag
# Checking GDAL data type and nodata value...
#
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: flowdir_hydro_mc_006.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_006.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting streams_mc_006 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_006.tif
# Using GDAL data type <Int16>
# Exporting raster data to GTiff format...
# ERROR 6: streams_hydro_mc_006.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_006.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting basins_mc_006 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_006.tif
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: basins_hydro_mc_006.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_006.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting pert_mc_006 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/perturbation_mc_006.tif
# Using GDAL data type <Float64>
# Input raster map contains cells with NULL-value (no-data). The value nan
# will be used to represent no-data values in the input map. You can specify
# a nodata value with the nodata option.
# Exporting raster data to GTiff format...
# ERROR 6: perturbation_mc_006.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/perturbation_mc_006.tif> created.
# Raster MASK removed
# Removing raster <accum_mc_006>
# ✅ Finished hydrology for DEM 'hybrid_dem_006' (tag='_mc_006')
# Removing raster <basins_mc_006>
# Removing raster <bed_dem_006>
# Removing raster <bed_masked_006>
# Removing raster <bed_mc_006>
# Removing raster <dem_filledA_006>
# Removing raster <dem_filledB_006>
# Removing raster <dem_mc_006>
# Removing raster <flow_dirA_006>
# Removing raster <flow_dirB_006>
# Removing raster <flow_dir_mc_006>
# Removing raster <hybrid_dem_006>
# Removing raster <inside_mask_006>
# Removing raster <noise_corr_bed_006>
# Removing raster <noise_raw_bed_006>
# Removing raster <outside_mask_006>
# Removing raster <pert_bed_006>
# Removing raster <pert_mc_006>
# Removing raster <streams_mc_006>
# Removing raster <surface_dem_smooth_006>
# Removing raster <surface_masked_006>
# ==================== Monte Carlo Run 007/500 ====================
# ERROR: No existing MASK to remove
# ✓ Created perturbation: pert_mc_007
# ✓ Created perturbed DEM: dem_mc_007
# ERROR: No existing MASK to remove
#
#
# ERROR: No existing MASK to remove
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 14583 unresolved areas
# Repeat to get the final directions...
# Found 631 unresolved areas
# Writing output raster maps...
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 75099 unresolved areas
# Repeat to get the final directions...
# Found 6249 unresolved areas
# Writing output raster maps...
# projection: 99 (WGS 84 / NSIDC Sea Ice Polar Stereographic North)
# zone:       0
# datum:      wgs84
# ellipsoid:  wgs84
# north:      -790000
# south:      -3308300
# west:       -619900
# east:       837000
# nsres:      100
# ewres:      100
# rows:       25183
# cols:       14569
# cells:      366891127
# ✓ Mask set from ice_mask_rast
# 🔧 Running r.watershed on hybrid_dem_007
# All subsequent raster operations will be limited to the MASK area. Removing
# or renaming raster map named 'MASK' will restore raster operations to
# normal.
# SECTION 1 beginning: Initiating Variables. 4 sections total.
# SECTION 1a: Mark masked and NULL cells
#
# SECTION 1b: Determining Offmap Flow.
#
# SECTION 2: A* Search.
#
# SECTION 3a: Accumulating Surface Flow with MFD.
#
# SECTION 3b: Adjusting drainage directions.
# SECTION 4: Closing Maps.
# Closing accumulation map
#
# Closing flow direction map
# ✓ r.watershed completed
# Loading input raster maps...
#
# Initializing A* search...
#
# A* Search...
#
# Extracting streams...
#
# Thinning stream segments...
#
# Writing output raster maps...
#
# Memory swap calculation (may take some time)...
# Reading raster map <flow_dir_mc_007>...
#
# Calculating basins using streams...
# Reading raster map <streams_mc_007>...
#
# Finding nodes...
#
# Delineating basins for 675 outlets...
#
# Writing raster map <basins_mc_007>...
# ✓ r.stream.basins completed
# 📤 Exporting hybrid_dem_007 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_007.tif
# ❌ Failed to export hybrid_dem_007: Module run `r.out.gdal --o input=hybrid_dem_007 output=/Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_007.tif format=GTiff type=Float32 createopt=COMPRESS=LZW,TILED=YES,BIGTIFF=YES nodata=-9999` ended with an error.
# The subprocess ended with a non-zero return code: 1. See errors above the traceback or in the error output.
# 📤 Exporting flow_dir_mc_007 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_007.tif
# WARNING: Precision loss: Float32 can not preserve the DCELL precision of
#          raster <hybrid_dem_007>. This can be avoided by using Float64
# ERROR: Raster export aborted. To override data loss check, use the -f flag
# Checking GDAL data type and nodata value...
#
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: flowdir_hydro_mc_007.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_007.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting streams_mc_007 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_007.tif
# Using GDAL data type <Int16>
# Exporting raster data to GTiff format...
# ERROR 6: streams_hydro_mc_007.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_007.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting basins_mc_007 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_007.tif
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: basins_hydro_mc_007.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_007.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting pert_mc_007 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/perturbation_mc_007.tif
# Using GDAL data type <Float64>
# Input raster map contains cells with NULL-value (no-data). The value nan
# will be used to represent no-data values in the input map. You can specify
# a nodata value with the nodata option.
# Exporting raster data to GTiff format...
# ERROR 6: perturbation_mc_007.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/perturbation_mc_007.tif> created.
# Raster MASK removed
# Removing raster <accum_mc_007>
# Removing raster <basins_mc_007>
# Removing raster <bed_dem_007>
# Removing raster <bed_masked_007>
# Removing raster <bed_mc_007>
# Removing raster <dem_filledA_007>
# Removing raster <dem_filledB_007>
# Removing raster <dem_mc_007>
# Removing raster <flow_dirA_007>
# Removing raster <flow_dirB_007>
# Removing raster <flow_dir_mc_007>
# Removing raster <hybrid_dem_007>
# Removing raster <inside_mask_007>
# Removing raster <noise_corr_bed_007>
# ✅ Finished hydrology for DEM 'hybrid_dem_007' (tag='_mc_007')
# Removing raster <noise_raw_bed_007>
# Removing raster <outside_mask_007>
# Removing raster <pert_bed_007>
# Removing raster <pert_mc_007>
# Removing raster <streams_mc_007>
# Removing raster <surface_dem_smooth_007>
# Removing raster <surface_masked_007>
# ==================== Monte Carlo Run 008/500 ====================
# ERROR: No existing MASK to remove
# ✓ Created perturbation: pert_mc_008
# ✓ Created perturbed DEM: dem_mc_008
# ERROR: No existing MASK to remove
#
#
# ERROR: No existing MASK to remove
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 14619 unresolved areas
# Repeat to get the final directions...
# Found 621 unresolved areas
# Writing output raster maps...
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 75204 unresolved areas
# Repeat to get the final directions...
# Found 6097 unresolved areas
# Writing output raster maps...
# projection: 99 (WGS 84 / NSIDC Sea Ice Polar Stereographic North)
# zone:       0
# datum:      wgs84
# ellipsoid:  wgs84
# north:      -790000
# south:      -3308300
# west:       -619900
# east:       837000
# nsres:      100
# ewres:      100
# rows:       25183
# cols:       14569
# cells:      366891127
# ✓ Mask set from ice_mask_rast
# 🔧 Running r.watershed on hybrid_dem_008
# All subsequent raster operations will be limited to the MASK area. Removing
# or renaming raster map named 'MASK' will restore raster operations to
# normal.
# SECTION 1 beginning: Initiating Variables. 4 sections total.
# SECTION 1a: Mark masked and NULL cells
#
# SECTION 1b: Determining Offmap Flow.
#
# SECTION 2: A* Search.
#
# SECTION 3a: Accumulating Surface Flow with MFD.
#
# SECTION 3b: Adjusting drainage directions.
# SECTION 4: Closing Maps.
# Closing accumulation map
#
# Closing flow direction map
# ✓ r.watershed completed
# Loading input raster maps...
#
# Initializing A* search...
#
# A* Search...
#
# Extracting streams...
#
# Thinning stream segments...
#
# Writing output raster maps...
#
# Memory swap calculation (may take some time)...
# Reading raster map <flow_dir_mc_008>...
#
# Calculating basins using streams...
# Reading raster map <streams_mc_008>...
#
# Finding nodes...
#
# Delineating basins for 683 outlets...
#
# Writing raster map <basins_mc_008>...
# ✓ r.stream.basins completed
# 📤 Exporting hybrid_dem_008 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_008.tif
# ❌ Failed to export hybrid_dem_008: Module run `r.out.gdal --o input=hybrid_dem_008 output=/Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_008.tif format=GTiff type=Float32 createopt=COMPRESS=LZW,TILED=YES,BIGTIFF=YES nodata=-9999` ended with an error.
# The subprocess ended with a non-zero return code: 1. See errors above the traceback or in the error output.
# 📤 Exporting flow_dir_mc_008 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_008.tif
# WARNING: Precision loss: Float32 can not preserve the DCELL precision of
#          raster <hybrid_dem_008>. This can be avoided by using Float64
# ERROR: Raster export aborted. To override data loss check, use the -f flag
# Checking GDAL data type and nodata value...
#
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: flowdir_hydro_mc_008.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_008.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting streams_mc_008 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_008.tif
# Using GDAL data type <Int16>
# Exporting raster data to GTiff format...
# ERROR 6: streams_hydro_mc_008.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_008.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting basins_mc_008 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_008.tif
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: basins_hydro_mc_008.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_008.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting pert_mc_008 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/perturbation_mc_008.tif
# Using GDAL data type <Float64>
# Input raster map contains cells with NULL-value (no-data). The value nan
# will be used to represent no-data values in the input map. You can specify
# a nodata value with the nodata option.
# Exporting raster data to GTiff format...
# ERROR 6: perturbation_mc_008.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/perturbation_mc_008.tif> created.
# Raster MASK removed
# Removing raster <accum_mc_008>
# Removing raster <basins_mc_008>
# Removing raster <bed_dem_008>
# Removing raster <bed_masked_008>
# Removing raster <bed_mc_008>
# Removing raster <dem_filledA_008>
# Removing raster <dem_filledB_008>
# Removing raster <dem_mc_008>
# Removing raster <flow_dirA_008>
# Removing raster <flow_dirB_008>
# Removing raster <flow_dir_mc_008>
# ✅ Finished hydrology for DEM 'hybrid_dem_008' (tag='_mc_008')
# Removing raster <hybrid_dem_008>
# Removing raster <inside_mask_008>
# Removing raster <noise_corr_bed_008>
# Removing raster <noise_raw_bed_008>
# Removing raster <outside_mask_008>
# Removing raster <pert_bed_008>
# Removing raster <pert_mc_008>
# Removing raster <streams_mc_008>
# Removing raster <surface_dem_smooth_008>
# Removing raster <surface_masked_008>
# ==================== Monte Carlo Run 009/500 ====================
# ERROR: No existing MASK to remove
# ✓ Created perturbation: pert_mc_009
# ✓ Created perturbed DEM: dem_mc_009
# ERROR: No existing MASK to remove
#
#
# ERROR: No existing MASK to remove
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 14582 unresolved areas
# Repeat to get the final directions...
# Found 623 unresolved areas
# Writing output raster maps...
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 74849 unresolved areas
# Repeat to get the final directions...
# Found 6173 unresolved areas
# Writing output raster maps...
# projection: 99 (WGS 84 / NSIDC Sea Ice Polar Stereographic North)
# zone:       0
# datum:      wgs84
# ellipsoid:  wgs84
# north:      -790000
# south:      -3308300
# west:       -619900
# east:       837000
# nsres:      100
# ewres:      100
# rows:       25183
# cols:       14569
# cells:      366891127
# ✓ Mask set from ice_mask_rast
# 🔧 Running r.watershed on hybrid_dem_009
# All subsequent raster operations will be limited to the MASK area. Removing
# or renaming raster map named 'MASK' will restore raster operations to
# normal.
# SECTION 1 beginning: Initiating Variables. 4 sections total.
# SECTION 1a: Mark masked and NULL cells
#
# SECTION 1b: Determining Offmap Flow.
#
# SECTION 2: A* Search.
#
# SECTION 3a: Accumulating Surface Flow with MFD.
#
# SECTION 3b: Adjusting drainage directions.
# SECTION 4: Closing Maps.
# Closing accumulation map
#
# Closing flow direction map
# ✓ r.watershed completed
# Loading input raster maps...
#
# Initializing A* search...
#
# A* Search...
#
# Extracting streams...
#
# Thinning stream segments...
#
# Writing output raster maps...
#
# Memory swap calculation (may take some time)...
# Reading raster map <flow_dir_mc_009>...
#
# Calculating basins using streams...
# Reading raster map <streams_mc_009>...
#
# Finding nodes...
#
# Delineating basins for 683 outlets...
#
# Writing raster map <basins_mc_009>...
# ✓ r.stream.basins completed
# 📤 Exporting hybrid_dem_009 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_009.tif
# ❌ Failed to export hybrid_dem_009: Module run `r.out.gdal --o input=hybrid_dem_009 output=/Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_009.tif format=GTiff type=Float32 createopt=COMPRESS=LZW,TILED=YES,BIGTIFF=YES nodata=-9999` ended with an error.
# The subprocess ended with a non-zero return code: 1. See errors above the traceback or in the error output.
# 📤 Exporting flow_dir_mc_009 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_009.tif
# WARNING: Precision loss: Float32 can not preserve the DCELL precision of
#          raster <hybrid_dem_009>. This can be avoided by using Float64
# ERROR: Raster export aborted. To override data loss check, use the -f flag
# Checking GDAL data type and nodata value...
#
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: flowdir_hydro_mc_009.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_009.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting streams_mc_009 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_009.tif
# Using GDAL data type <Int16>
# Exporting raster data to GTiff format...
# ERROR 6: streams_hydro_mc_009.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_009.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting basins_mc_009 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_009.tif
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: basins_hydro_mc_009.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_009.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting pert_mc_009 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/perturbation_mc_009.tif
# Using GDAL data type <Float64>
# Input raster map contains cells with NULL-value (no-data). The value nan
# will be used to represent no-data values in the input map. You can specify
# a nodata value with the nodata option.
# Exporting raster data to GTiff format...
# ERROR 6: perturbation_mc_009.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/perturbation_mc_009.tif> created.
# Raster MASK removed
# Removing raster <accum_mc_009>
# Removing raster <basins_mc_009>
# Removing raster <bed_dem_009>
# Removing raster <bed_masked_009>
# Removing raster <bed_mc_009>
# Removing raster <dem_filledA_009>
# Removing raster <dem_filledB_009>
# Removing raster <dem_mc_009>
# Removing raster <flow_dirA_009>
# Removing raster <flow_dirB_009>
# ...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 74888 unresolved areas
# Repeat to get the final directions...
# Found 6067 unresolved areas
# Writing output raster maps...
# projection: 99 (WGS 84 / NSIDC Sea Ice Polar Stereographic North)
# zone:       0
# datum:      wgs84
# ellipsoid:  wgs84
# north:      -790000
# south:      -3308300
# west:       -619900
# east:       837000
# nsres:      100
# ewres:      100
# rows:       25183
# cols:       14569
# cells:      366891127
# ✓ Mask set from ice_mask_rast
# 🔧 Running r.watershed on hybrid_dem_010
# All subsequent raster operations will be limited to the MASK area. Removing
# or renaming raster map named 'MASK' will restore raster operations to
# normal.
# SECTION 1 beginning: Initiating Variables. 4 sections total.
# SECTION 1a: Mark masked and NULL cells
#
# SECTION 1b: Determining Offmap Flow.
#
# SECTION 2: A* Search.
#
# SECTION 3a: Accumulating Surface Flow with MFD.
#
# SECTION 3b: Adjusting drainage directions.
# SECTION 4: Closing Maps.
# Closing accumulation map
#
# Closing flow direction map
# ✓ r.watershed completed
# Loading input raster maps...
#
# Initializing A* search...
#
# A* Search...
#
# Extracting streams...
#
# Thinning stream segments...
#
# Writing output raster maps...
#
# Memory swap calculation (may take some time)...
# Reading raster map <flow_dir_mc_010>...
#
# Calculating basins using streams...
# Reading raster map <streams_mc_010>...
#
# Finding nodes...
#
# Delineating basins for 664 outlets...
#
# Writing raster map <basins_mc_010>...
# ✓ r.stream.basins completed
# 📤 Exporting hybrid_dem_010 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_010.tif
# ❌ Failed to export hybrid_dem_010: Module run `r.out.gdal --o input=hybrid_dem_010 output=/Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_010.tif format=GTiff type=Float32 createopt=COMPRESS=LZW,TILED=YES,BIGTIFF=YES nodata=-9999` ended with an error.
# The subprocess ended with a non-zero return code: 1. See errors above the traceback or in the error output.
# 📤 Exporting flow_dir_mc_010 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_010.tif
# WARNING: Precision loss: Float32 can not preserve the DCELL precision of
#          raster <hybrid_dem_010>. This can be avoided by using Float64
# ERROR: Raster export aborted. To override data loss check, use the -f flag
# Checking GDAL data type and nodata value...
#
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: flowdir_hydro_mc_010.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_010.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting streams_mc_010 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_010.tif
# Using GDAL data type <Int16>
# Exporting raster data to GTiff format...
# ERROR 6: streams_hydro_mc_010.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_010.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting basins_mc_010 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_010.tif
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: basins_hydro_mc_010.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_010.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting pert_mc_010 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/perturbation_mc_010.tif
# Using GDAL data type <Float64>
# Input raster map contains cells with NULL-value (no-data). The value nan
# will be used to represent no-data values in the input map. You can specify
# a nodata value with the nodata option.
# Exporting raster data to GTiff format...
# ERROR 6: perturbation_mc_010.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/perturbation_mc_010.tif> created.
# Raster MASK removed
# Removing raster <accum_mc_010>
# Removing raster <basins_mc_010>
# Removing raster <bed_dem_010>
# Removing raster <bed_masked_010>
# Removing raster <bed_mc_010>
# Removing raster <dem_filledA_010>
# Removing raster <dem_filledB_010>
# Removing raster <dem_mc_010>
# Removing raster <flow_dirA_010>
# Removing raster <flow_dirB_010>
# Removing raster <flow_dir_mc_010>
# Removing raster <hybrid_dem_010>
# ✅ Finished hydrology for DEM 'hybrid_dem_010' (tag='_mc_010')
# Removing raster <inside_mask_010>
# Removing raster <noise_corr_bed_010>
# Removing raster <noise_raw_bed_010>
# Removing raster <outside_mask_010>
# Removing raster <pert_bed_010>
# Removing raster <pert_mc_010>
# Removing raster <streams_mc_010>
# Removing raster <surface_dem_smooth_010>
# Removing raster <surface_masked_010>
# ==================== Monte Carlo Run 011/500 ====================
# ERROR: No existing MASK to remove
# ✓ Created perturbation: pert_mc_011
# ✓ Created perturbed DEM: dem_mc_011
# ERROR: No existing MASK to remove
#
#
# ERROR: No existing MASK to remove
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 14609 unresolved areas
# Repeat to get the final directions...
# Found 637 unresolved areas
# Writing output raster maps...
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 74762 unresolved areas
# Repeat to get the final directions...
# Found 6156 unresolved areas
# Writing output raster maps...
# projection: 99 (WGS 84 / NSIDC Sea Ice Polar Stereographic North)
# zone:       0
# datum:      wgs84
# ellipsoid:  wgs84
# north:      -790000
# south:      -3308300
# west:       -619900
# east:       837000
# nsres:      100
# ewres:      100
# rows:       25183
# cols:       14569
# cells:      366891127
# ✓ Mask set from ice_mask_rast
# 🔧 Running r.watershed on hybrid_dem_011
# All subsequent raster operations will be limited to the MASK area. Removing
# or renaming raster map named 'MASK' will restore raster operations to
# normal.
# SECTION 1 beginning: Initiating Variables. 4 sections total.
# SECTION 1a: Mark masked and NULL cells
#
# SECTION 1b: Determining Offmap Flow.
#
# SECTION 2: A* Search.
#
# SECTION 3a: Accumulating Surface Flow with MFD.
#
# SECTION 3b: Adjusting drainage directions.
# SECTION 4: Closing Maps.
# Closing accumulation map
#
# Closing flow direction map
# ✓ r.watershed completed
# Loading input raster maps...
#
# Initializing A* search...
#
# A* Search...
#
# Extracting streams...
#
# Thinning stream segments...
#
# Writing output raster maps...
#
# Memory swap calculation (may take some time)...
# Reading raster map <flow_dir_mc_011>...
#
# Calculating basins using streams...
# Reading raster map <streams_mc_011>...
#
# Finding nodes...
#
# Delineating basins for 677 outlets...
#
# Writing raster map <basins_mc_011>...
# ✓ r.stream.basins completed
# 📤 Exporting hybrid_dem_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_011.tif
# ❌ Failed to export hybrid_dem_011: Module run `r.out.gdal --o input=hybrid_dem_011 output=/Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_hydro_mc_011.tif format=GTiff type=Float32 createopt=COMPRESS=LZW,TILED=YES,BIGTIFF=YES nodata=-9999` ended with an error.
# The subprocess ended with a non-zero return code: 1. See errors above the traceback or in the error output.
# 📤 Exporting flow_dir_mc_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_011.tif
# WARNING: Precision loss: Float32 can not preserve the DCELL precision of
#          raster <hybrid_dem_011>. This can be avoided by using Float64
# ERROR: Raster export aborted. To override data loss check, use the -f flag
# Checking GDAL data type and nodata value...
#
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: flowdir_hydro_mc_011.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/flowdir_hydro_mc_011.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting streams_mc_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_011.tif
# Using GDAL data type <Int16>
# Exporting raster data to GTiff format...
# ERROR 6: streams_hydro_mc_011.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/streams_hydro_mc_011.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting basins_mc_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_011.tif
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: basins_hydro_mc_011.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/basins_hydro_mc_011.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exporting pert_mc_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/perturbation_mc_011.tif
# Using GDAL data type <Float64>
# Input raster map contains cells with NULL-value (no-data). The value nan
# will be used to represent no-data values in the input map. You can specify
# a nodata value with the nodata option.
# Exporting raster data to GTiff format...
# ERROR 6: perturbation_mc_011.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/perturbation_mc_011.tif> created.
# Raster MASK removed
# ✅ Finished hydrology for DEM 'hybrid_dem_011' (tag='_mc_011')
# Checking GDAL data type and nodata value...
#
# Using GDAL data type <Float64>
# Exporting raster data to GTiff format...
# WARNING: Too many values, color table cut to 65535 entries
# ERROR 6: accum_hybrid_mc_011.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/accum_hybrid_mc_011.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exported accum_mc_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/accum_hybrid_mc_011.tif
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: flowdir_hybrid_mc_011.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/flowdir_hybrid_mc_011.tif> created.
# WARNING: Color table of raster map <streams_mc_011> not found
# Checking GDAL data type and nodata value...
# 📤 Exported flow_dir_mc_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/flowdir_hybrid_mc_011.tif
# Using GDAL data type <Int16>
# Exporting raster data to GTiff format...
# ERROR 6: streams_hybrid_mc_011.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/streams_hybrid_mc_011.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exported streams_mc_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/streams_hybrid_mc_011.tif
# Using GDAL data type <Int32>
# Exporting raster data to GTiff format...
# ERROR 6: basins_hybrid_mc_011.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/basins_hybrid_mc_011.tif> created.
# WARNING: Color table of raster map <hybrid_dem_011> not found
# Checking GDAL data type and nodata value...
# 📤 Exported basins_mc_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/basins_hybrid_mc_011.tif
# Using GDAL data type <Float64>
# Exporting raster data to GTiff format...
# ERROR 6: hybrid_dem_011.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/hybrid_dem_011.tif> created.
# WARNING: Color table of raster map <bed_masked_011> not found
# Checking GDAL data type and nodata value...
# 📤 Exported hybrid_dem_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/hybrid_dem_011.tif
# Using GDAL data type <Float64>
# Exporting raster data to GTiff format...
# ERROR 6: bed_masked_011.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/bed_masked_011.tif> created.
# WARNING: Color table of raster map <surface_masked_011> not found
# Checking GDAL data type and nodata value...
# 📤 Exported bed_masked_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/bed_masked_011.tif
# Using GDAL data type <Float64>
# Exporting raster data to GTiff format...
# ERROR 6: surface_masked_011.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/surface_masked_011.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exported surface_masked_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/surface_masked_011.tif
# Using GDAL data type <Float64>
# Exporting raster data to GTiff format...
# ERROR 6: dem_filledA_011.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/dem_filledA_011.tif> created.
# Checking GDAL data type and nodata value...
# 📤 Exported dem_filledA_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_filledA_011.tif
# Using GDAL data type <Float64>
# Exporting raster data to GTiff format...
# ERROR 6: dem_filledB_011.tif, band 1: SetColorTable() only supported for Byte or UInt16 bands in TIFF format.
#
# r.out.gdal complete. File </Volumes/Lenovo
# PS8/4DBasins/hybrid_100_mc/dem_filledB_011.tif> created.
# Removing raster <accum_mc_011>
# Removing raster <basins_mc_011>
# Removing raster <bed_dem_011>
# Removing raster <bed_masked_011>
# Removing raster <bed_mc_011>
# Removing raster <dem_filledA_011>
# Removing raster <dem_filledB_011>
# Removing raster <dem_mc_011>
# Removing raster <flow_dirA_011>
# Removing raster <flow_dirB_011>
# Removing raster <flow_dir_mc_011>
# Removing raster <hybrid_dem_011>
# Removing raster <inside_mask_011>
# 📤 Exported dem_filledB_011 → /Volumes/Lenovo PS8/4DBasins/hybrid_100_mc/dem_filledB_011.tif
# Removing raster <noise_corr_bed_011>
# Removing raster <noise_raw_bed_011>
# Removing raster <outside_mask_011>
# Removing raster <pert_bed_011>
# Removing raster <pert_mc_011>
# Removing raster <streams_mc_011>
# Removing raster <surface_dem_smooth_011>
# Removing raster <surface_masked_011>
# ==================== Monte Carlo Run 012/500 ====================
# ERROR: No existing MASK to remove
# ✓ Created perturbation: pert_mc_012
# ✓ Created perturbed DEM: dem_mc_012
# ERROR: No existing MASK to remove
#
#
# ERROR: No existing MASK to remove
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 14643 unresolved areas
# Repeat to get the final directions...
# Found 648 unresolved areas
# Writing output raster maps...
#
# Reading input elevation raster map...
#
# Filling sinks...
# Determining flow directions for ambiguous cases...
# Found 75210 unresolved areas
# Repeat to get the final directions...
# Found 6183 unresolved areas
# Writing output raster maps...
# projection: 99 (WGS 84 / NSIDC Sea Ice Polar Stereographic North)
# zone:       0
# datum:      wgs84
# ellipsoid:  wgs84
# north:      -790000
# south:      -3308300
# west:       -619900
# east:       837000
# nsres:      100
# ewres:      100
# rows:       25183
# cols:       14569
# cells:      366891127
# ✓ Mask set from ice_mask_rast
# 🔧 Running r.watershed on hybrid_dem_012
# All subsequent raster operations will be limited to the MASK area. Removing
# or renaming raster map named 'MASK' will restore raster operations to
# normal.
# SECTION 1 beginning: Initiating Variables. 4 sections total.
# SECTION 1a: Mark masked and NULL cells
#
# SECTION 1b: Determining Offmap Flow.
#
# SECTION 2: A* Search.
#
# SECTION 3a: Accumulating Surface Flow with MFD.
#
# SECTION 3b: Adjusting drainage directions.
# SECTION 4: Closing Maps.
# Closing accumulation map
#
# Closing flow direction map
# ✓ r.watershed completed
# Loading input raster maps...

# %%
# --------------------------------------------------------------------
# POST-PROCESS MC REALISATIONS
# --------------------------------------------------------------------
build_mc_products(
    mc_dir=OUT,
    basin_pattern=BASIN_PATTERN,
    ref_index=0,
    chunk_rows=32,
    p_stable_pixel=0.80,
    p_stable_edge=0.45,
    p_min_div=0.00,
)
# Out:
# Found 301 basin realisations
# Using basins_hydro_mc_000.tif as label grid / domain
# Max reference basin ID: 12593
#
# Mapping run 1/301: basins_hydro_mc_000.tif
#
# Mapping run 2/301: basins_hydro_mc_001.tif
#
# Mapping run 3/301: basins_hydro_mc_002.tif
#
# Mapping run 4/301: basins_hydro_mc_003.tif
#
# Mapping run 5/301: basins_hydro_mc_004.tif
#
# Mapping run 6/301: basins_hydro_mc_005.tif
#
# Mapping run 7/301: basins_hydro_mc_006.tif
#
# Mapping run 8/301: basins_hydro_mc_007.tif
#
# Mapping run 9/301: basins_hydro_mc_008.tif
#
# Mapping run 10/301: basins_hydro_mc_009.tif
#
# Mapping run 11/301: basins_hydro_mc_010.tif
#
# Mapping run 12/301: basins_hydro_mc_011.tif
#
# Mapping run 13/301: basins_hydro_mc_012.tif
#
# Mapping run 14/301: basins_hydro_mc_013.tif
#
# Mapping run 15/301: basins_hydro_mc_014.tif
#
# Mapping run 16/301: basins_hydro_mc_015.tif
#
# Mapping run 17/301: basins_hydro_mc_016.tif
#
# Mapping run 18/301: basins_hydro_mc_017.tif
#
# Mapping run 19/301: basins_hydro_mc_018.tif
#
# Mapping run 20/301: basins_hydro_mc_019.tif
#
# Mapping run 21/301: basins_hydro_mc_020.tif
#
# Mapping run 22/301: basins_hydro_mc_021.tif
#
# Mapping run 23/301: basins_hydro_mc_022.tif
#
# Mapping run 24/301: basins_hydro_mc_023.tif
#
# Mapping run 25/301: basins_hydro_mc_024.tif
#
# Mapping run 26/301: basins_hydro_mc_025.tif
#
# Mapping run 27/301: basins_hydro_mc_026.tif
#
# Mapping run 28/301: basins_hydro_mc_027.tif
#
# Mapping run 29/301: basins_hydro_mc_028.tif
#
# Mapping run 30/301: basins_hydro_mc_029.tif
#
# Mapping run 31/301: basins_hydro_mc_030.tif
#
# Mapping run 32/301: basins_hydro_mc_031.tif
#
# Mapping run 33/301: basins_hydro_mc_032.tif
#
# Mapping run 34/301: basins_hydro_mc_033.tif
#
# Mapping run 35/301: basins_hydro_mc_034.tif
#
# Mapping run 36/301: basins_hydro_mc_035.tif
#
# Mapping run 37/301: basins_hydro_mc_036.tif
#
# Mapping run 38/301: basins_hydro_mc_037.tif
#
# Mapping run 39/301: basins_hydro_mc_038.tif
#
# Mapping run 40/301: basins_hydro_mc_039.tif
#
# Mapping run 41/301: basins_hydro_mc_040.tif
#
# Mapping run 42/301: basins_hydro_mc_041.tif
#
# Mapping run 43/301: basins_hydro_mc_042.tif
#
# Mapping run 44/301: basins_hydro_mc_043.tif
#
# Mapping run 45/301: basins_hydro_mc_044.tif
#
# Mapping run 46/301: basins_hydro_mc_045.tif
#
# Mapping run 47/301: basins_hydro_mc_046.tif
#
# Mapping run 48/301: basins_hydro_mc_047.tif
#
# Mapping run 49/301: basins_hydro_mc_048.tif
#
# Mapping run 50/301: basins_hydro_mc_049.tif
#
# Mapping run 51/301: basins_hydro_mc_050.tif
#
# Mapping run 52/301: basins_hydro_mc_051.tif
#
# Mapping run 53/301: basins_hydro_mc_052.tif
#
# Mapping run 54/301: basins_hydro_mc_053.tif
#
# Mapping run 55/301: basins_hydro_mc_054.tif
#
# Mapping run 56/301: basins_hydro_mc_055.tif
#
# Mapping run 57/301: basins_hydro_mc_056.tif
#
# Mapping run 58/301: basins_hydro_mc_057.tif
#
# Mapping run 59/301: basins_hydro_mc_058.tif
#
# Mapping run 60/301: basins_hydro_mc_059.tif
#
# Mapping run 61/301: basins_hydro_mc_060.tif
#
# Mapping run 62/301: basins_hydro_mc_061.tif
#
# Mapping run 63/301: basins_hydro_mc_062.tif
#
# Mapping run 64/301: basins_hydro_mc_063.tif
#
# Mapping run 65/301: basins_hydro_mc_064.tif
#
# Mapping run 66/301: basins_hydro_mc_065.tif

# %%
from mc_postprocess_2 import (
    build_mc_products,
    make_perturbed_dem,
)

# --------------------------------------------------------------------
# POST-PROCESS MC REALISATIONS
# --------------------------------------------------------------------
build_mc_products(
    mc_dir=OUT,
    basin_pattern="basins_hydro_mc_*.tif",
    ref_index=0,
    chunk_rows=32,
    p_stable_pixel=0.80,  # stable vs uncertain divides
    p_stable_edge=0.45,   # currently unused (no global merging)
    p_min_div=0.00,
)
# Out:
# Found 501 basin realisations
# Using basins_hydro_mc_000.tif as label grid / domain
# Max reference basin ID: 12593
#
# Mapping run 1/501: basins_hydro_mc_000.tif
#
# Mapping run 2/501: basins_hydro_mc_001.tif
#
# Mapping run 3/501: basins_hydro_mc_002.tif
#
# Mapping run 4/501: basins_hydro_mc_003.tif
#
# Mapping run 5/501: basins_hydro_mc_004.tif
#
# Mapping run 6/501: basins_hydro_mc_005.tif
#
# Mapping run 7/501: basins_hydro_mc_006.tif
#
# Mapping run 8/501: basins_hydro_mc_007.tif
#
# Mapping run 9/501: basins_hydro_mc_008.tif
#
# Mapping run 10/501: basins_hydro_mc_009.tif
#
# Mapping run 11/501: basins_hydro_mc_010.tif
#
# Mapping run 12/501: basins_hydro_mc_011.tif
#
# Mapping run 13/501: basins_hydro_mc_012.tif
#
# Mapping run 14/501: basins_hydro_mc_013.tif
#
# Mapping run 15/501: basins_hydro_mc_014.tif
#
# Mapping run 16/501: basins_hydro_mc_015.tif
#
# Mapping run 17/501: basins_hydro_mc_016.tif
#
# Mapping run 18/501: basins_hydro_mc_017.tif
#
# Mapping run 19/501: basins_hydro_mc_018.tif
#
# Mapping run 20/501: basins_hydro_mc_019.tif
#
# Mapping run 21/501: basins_hydro_mc_020.tif
#
# Mapping run 22/501: basins_hydro_mc_021.tif
#
# Mapping run 23/501: basins_hydro_mc_022.tif
#
# Mapping run 24/501: basins_hydro_mc_023.tif
#
# Mapping run 25/501: basins_hydro_mc_024.tif
#
# Mapping run 26/501: basins_hydro_mc_025.tif
#
# Mapping run 27/501: basins_hydro_mc_026.tif
#
# Mapping run 28/501: basins_hydro_mc_027.tif
#
# Mapping run 29/501: basins_hydro_mc_028.tif
#
# Mapping run 30/501: basins_hydro_mc_029.tif
#
# Mapping run 31/501: basins_hydro_mc_030.tif
#
# Mapping run 32/501: basins_hydro_mc_031.tif
#
# Mapping run 33/501: basins_hydro_mc_032.tif
#
# Mapping run 34/501: basins_hydro_mc_033.tif
#
# Mapping run 35/501: basins_hydro_mc_034.tif
#
# Mapping run 36/501: basins_hydro_mc_035.tif
#
# Mapping run 37/501: basins_hydro_mc_036.tif
#
# Mapping run 38/501: basins_hydro_mc_037.tif
#
# Mapping run 39/501: basins_hydro_mc_038.tif
#
# Mapping run 40/501: basins_hydro_mc_039.tif
#
# Mapping run 41/501: basins_hydro_mc_040.tif
#
# Mapping run 42/501: basins_hydro_mc_041.tif
#
# Mapping run 43/501: basins_hydro_mc_042.tif
#
# Mapping run 44/501: basins_hydro_mc_043.tif
#
# Mapping run 45/501: basins_hydro_mc_044.tif
#
# Mapping run 46/501: basins_hydro_mc_045.tif
#
# Mapping run 47/501: basins_hydro_mc_046.tif
#
# Mapping run 48/501: basins_hydro_mc_047.tif
#
# Mapping run 49/501: basins_hydro_mc_048.tif
#
# Mapping run 50/501: basins_hydro_mc_049.tif
#
# Mapping run 51/501: basins_hydro_mc_050.tif
#
# Mapping run 52/501: basins_hydro_mc_051.tif
#
# Mapping run 53/501: basins_hydro_mc_052.tif
#
# Mapping run 54/501: basins_hydro_mc_053.tif
#
# Mapping run 55/501: basins_hydro_mc_054.tif
#
# Mapping run 56/501: basins_hydro_mc_055.tif
#
# Mapping run 57/501: basins_hydro_mc_056.tif
#
# Mapping run 58/501: basins_hydro_mc_057.tif
#
# Mapping run 59/501: basins_hydro_mc_058.tif
#
# Mapping run 60/501: basins_hydro_mc_059.tif
#
# Mapping run 61/501: basins_hydro_mc_060.tif
#
# Mapping run 62/501: basins_hydro_mc_061.tif
#
# Mapping run 63/501: basins_hydro_mc_062.tif
#
# Mapping run 64/501: basins_hydro_mc_063.tif
#
# Mapping run 65/501: basins_hydro_mc_064.tif
#
# Mapping run 66/501: basins_hydro_mc_065.tif
#
# Mapping run 67/501: basins_hydro_mc_066.tif
#
# Mapping run 68/501: basins_hydro_mc_067.tif
#
# Mapping run 69/501: basins_hydro_mc_068.tif
#
# Mapping run 70/501: basins_hydro_mc_069.tif
#
# Mapping run 71/501: basins_hydro_mc_070.tif
#
# Mapping run 72/501: basins_hydro_mc_071.tif
#
# Mapping run 73/501: basins_hydro_mc_072.tif
#
# Mapping run 74/501: basins_hydro_mc_073.tif
#
# Mapping run 75/501: basins_hydro_mc_074.tif
#
# Mapping run 76/501: basins_hydro_mc_075.tif
#
# Mapping run 77/501: basins_hydro_mc_076.tif
#
# Mapping run 78/501: basins_hydro_mc_077.tif
#
# Mapping run 79/501: basins_hydro_mc_078.tif
#
# Mapping run 80/501: basins_hydro_mc_079.tif
#
# Mapping run 81/501: basins_hydro_mc_080.tif
#
# Mapping run 82/501: basins_hydro_mc_081.tif
#
# Mapping run 83/501: basins_hydro_mc_082.tif
#
# Mapping run 84/501: basins_hydro_mc_083.tif
#
# Mapping run 85/501: basins_hydro_mc_084.tif
#
# Mapping run 86/501: basins_hydro_mc_085.tif
#
# Mapping run 87/501: basins_hydro_mc_086.tif
#
# Mapping run 88/501: basins_hydro_mc_087.tif
#
# Mapping run 89/501: basins_hydro_mc_088.tif
#
# Mapping run 90/501: basins_hydro_mc_089.tif
#
# Mapping run 91/501: basins_hydro_mc_090.tif
#
# Mapping run 92/501: basins_hydro_mc_091.tif
#
# Mapping run 93/501: basins_hydro_mc_092.tif
#
# Mapping run 94/501: basins_hydro_mc_093.tif
#
# Mapping run 95/501: basins_hydro_mc_094.tif
#
# Mapping run 96/501: basins_hydro_mc_095.tif
#
# Mapping run 97/501: basins_hydro_mc_096.tif
#
# Mapping run 98/501: basins_hydro_mc_097.tif
#
# Mapping run 99/501: basins_hydro_mc_098.tif
#
# Mapping run 100/501: basins_hydro_mc_099.tif
#
# Mapping run 101/501: basins_hydro_mc_100.tif
#
# Mapping run 102/501: basins_hydro_mc_101.tif
#
# Mapping run 103/501: basins_hydro_mc_102.tif
#
# Mapping run 104/501: basins_hydro_mc_103.tif
#
# Mapping run 105/501: basins_hydro_mc_104.tif
#
# Mapping run 106/501: basins_hydro_mc_105.tif
#
# Mapping run 107/501: basins_hydro_mc_106.tif
#
# Mapping run 108/501: basins_hydro_mc_107.tif
#
# Mapping run 109/501: basins_hydro_mc_108.tif
#
# Mapping run 110/501: basins_hydro_mc_109.tif
#
# Mapping run 111/501: basins_hydro_mc_110.tif
#
# Mapping run 112/501: basins_hydro_mc_111.tif
#
# Mapping run 113/501: basins_hydro_mc_112.tif
#
# Mapping run 114/501: basins_hydro_mc_113.tif
#
# Mapping run 115/501: basins_hydro_mc_114.tif
#
# Mapping run 116/501: basins_hydro_mc_115.tif
#
# Mapping run 117/501: basins_hydro_mc_116.tif
#
# Mapping run 118/501: basins_hydro_mc_117.tif
#
# Mapping run 119/501: basins_hydro_mc_118.tif
#
# Mapping run 120/501: basins_hydro_mc_119.tif
#
# Mapping run 121/501: basins_hydro_mc_120.tif
#
# Mapping run 122/501: basins_hydro_mc_121.tif
#
# Mapping run 123/501: basins_hydro_mc_122.tif
#
# Mapping run 124/501: basins_hydro_mc_123.tif
#
# Mapping run 125/501: basins_hydro_mc_124.tif
#
# Mapping run 126/501: basins_hydro_mc_125.tif
#
# Mapping run 127/501: basins_hydro_mc_126.tif
#
# Mapping run 128/501: basins_hydro_mc_127.tif
#
# Mapping run 129/501: basins_hydro_mc_128.tif
#
# Mapping run 130/501: basins_hydro_mc_129.tif
#
# Mapping run 131/501: basins_hydro_mc_130.tif
#
# Mapping run 132/501: basins_hydro_mc_131.tif
#
# Mapping run 133/501: basins_hydro_mc_132.tif
#
# Mapping run 134/501: basins_hydro_mc_133.tif
#
# Mapping run 135/501: basins_hydro_mc_134.tif
#
# Mapping run 136/501: basins_hydro_mc_135.tif
#
# Mapping run 137/501: basins_hydro_mc_136.tif
#
# Mapping run 138/501: basins_hydro_mc_137.tif
#
# Mapping run 139/501: basins_hydro_mc_138.tif
#
# Mapping run 140/501: basins_hydro_mc_139.tif
#
# Mapping run 141/501: basins_hydro_mc_140.tif
#
# Mapping run 142/501: basins_hydro_mc_141.tif
#
# Mapping run 143/501: basins_hydro_mc_142.tif
#
# Mapping run 144/501: basins_hydro_mc_143.tif
#
# Mapping run 145/501: basins_hydro_mc_144.tif
#
# Mapping run 146/501: basins_hydro_mc_145.tif
#
# Mapping run 147/501: basins_hydro_mc_146.tif
#
# Mapping run 148/501: basins_hydro_mc_147.tif
#
# Mapping run 149/501: basins_hydro_mc_148.tif
#
# Mapping run 150/501: basins_hydro_mc_149.tif
#
# Mapping run 151/501: basins_hydro_mc_150.tif
#
# Mapping run 152/501: basins_hydro_mc_151.tif
#
# Mapping run 153/501: basins_hydro_mc_152.tif
#
# Mapping run 154/501: basins_hydro_mc_153.tif
#
# Mapping run 155/501: basins_hydro_mc_154.tif
#
# Mapping run 156/501: basins_hydro_mc_155.tif
#
# Mapping run 157/501: basins_hydro_mc_156.tif
#
# Mapping run 158/501: basins_hydro_mc_157.tif
#
# Mapping run 159/501: basins_hydro_mc_158.tif
#
# Mapping run 160/501: basins_hydro_mc_159.tif
#
# Mapping run 161/501: basins_hydro_mc_160.tif
#
# Mapping run 162/501: basins_hydro_mc_161.tif
#
# Mapping run 163/501: basins_hydro_mc_162.tif
#
# Mapping run 164/501: basins_hydro_mc_163.tif
#
# Mapping run 165/501: basins_hydro_mc_164.tif
#
# Mapping run 166/501: basins_hydro_mc_165.tif
#
# Mapping run 167/501: basins_hydro_mc_166.tif
#
# Mapping run 168/501: basins_hydro_mc_167.tif
#
# Mapping run 169/501: basins_hydro_mc_168.tif
#
# Mapping run 170/501: basins_hydro_mc_169.tif
#
# Mapping run 171/501: basins_hydro_mc_170.tif
#
# Mapping run 172/501: basins_hydro_mc_171.tif
#
# Mapping run 173/501: basins_hydro_mc_172.tif
#
# Mapping run 174/501: basins_hydro_mc_173.tif
#
# Mapping run 175/501: basins_hydro_mc_174.tif
#
# Mapping run 176/501: basins_hydro_mc_175.tif
#
# Mapping run 177/501: basins_hydro_mc_176.tif
#
# Mapping run 178/501: basins_hydro_mc_177.tif
#
# Mapping run 179/501: basins_hydro_mc_178.tif
#
# Mapping run 180/501: basins_hydro_mc_179.tif
#
# Mapping run 181/501: basins_hydro_mc_180.tif
#
# Mapping run 182/501: basins_hydro_mc_181.tif
#
# Mapping run 183/501: basins_hydro_mc_182.tif
#
# Mapping run 184/501: basins_hydro_mc_183.tif
#
# Mapping run 185/501: basins_hydro_mc_184.tif
#
# Mapping run 186/501: basins_hydro_mc_185.tif
#
# Mapping run 187/501: basins_hydro_mc_186.tif
#
# Mapping run 188/501: basins_hydro_mc_187.tif
#
# Mapping run 189/501: basins_hydro_mc_188.tif
#
# Mapping run 190/501: basins_hydro_mc_189.tif
#
# Mapping run 191/501: basins_hydro_mc_190.tif
#
# Mapping run 192/501: basins_hydro_mc_191.tif
#
# Mapping run 193/501: basins_hydro_mc_192.tif
#
# Mapping run 194/501: basins_hydro_mc_193.tif
#
# Mapping run 195/501: basins_hydro_mc_194.tif
#
# Mapping run 196/501: basins_hydro_mc_195.tif
#
# Mapping run 197/501: basins_hydro_mc_196.tif
#
# Mapping run 198/501: basins_hydro_mc_197.tif
#
# Mapping run 199/501: basins_hydro_mc_198.tif
#
# Mapping run 200/501: basins_hydro_mc_199.tif
#
# Mapping run 201/501: basins_hydro_mc_200.tif
#
# Mapping run 202/501: basins_hydro_mc_201.tif
#
# Mapping run 203/501: basins_hydro_mc_202.tif
#
# Mapping run 204/501: basins_hydro_mc_203.tif
#
# Mapping run 205/501: basins_hydro_mc_204.tif
#
# Mapping run 206/501: basins_hydro_mc_205.tif
#
# Mapping run 207/501: basins_hydro_mc_206.tif
#
# Mapping run 208/501: basins_hydro_mc_207.tif
#
# Mapping run 209/501: basins_hydro_mc_208.tif
#
# Mapping run 210/501: basins_hydro_mc_209.tif
#
# Mapping run 211/501: basins_hydro_mc_210.tif
#
# Mapping run 212/501: basins_hydro_mc_211.tif
#
# Mapping run 213/501: basins_hydro_mc_212.tif
#
# Mapping run 214/501: basins_hydro_mc_213.tif
#
# Mapping run 215/501: basins_hydro_mc_214.tif
#
# Mapping run 216/501: basins_hydro_mc_215.tif
#
# Mapping run 217/501: basins_hydro_mc_216.tif
#
# Mapping run 218/501: basins_hydro_mc_217.tif
#
# Mapping run 219/501: basins_hydro_mc_218.tif
#
# Mapping run 220/501: basins_hydro_mc_219.tif
#
# Mapping run 221/501: basins_hydro_mc_220.tif
#
# Mapping run 222/501: basins_hydro_mc_221.tif
#
# Mapping run 223/501: basins_hydro_mc_222.tif
#
# Mapping run 224/501: basins_hydro_mc_223.tif
#
# Mapping run 225/501: basins_hydro_mc_224.tif
#
# Mapping run 226/501: basins_hydro_mc_225.tif
#
# Mapping run 227/501: basins_hydro_mc_226.tif
#
# Mapping run 228/501: basins_hydro_mc_227.tif
#
# Mapping run 229/501: basins_hydro_mc_228.tif
#
# Mapping run 230/501: basins_hydro_mc_229.tif
#
# Mapping run 231/501: basins_hydro_mc_230.tif
#
# Mapping run 232/501: basins_hydro_mc_231.tif
#
# Mapping run 233/501: basins_hydro_mc_232.tif
#
# Mapping run 234/501: basins_hydro_mc_233.tif
#
# Mapping run 235/501: basins_hydro_mc_234.tif
#
# Mapping run 236/501: basins_hydro_mc_235.tif
#
# Mapping run 237/501: basins_hydro_mc_236.tif
#
# Mapping run 238/501: basins_hydro_mc_237.tif
#
# Mapping run 239/501: basins_hydro_mc_238.tif
#
# Mapping run 240/501: basins_hydro_mc_239.tif
#
# Mapping run 241/501: basins_hydro_mc_240.tif
#
# Mapping run 242/501: basins_hydro_mc_241.tif
#
# Mapping run 243/501: basins_hydro_mc_242.tif
#
# Mapping run 244/501: basins_hydro_mc_243.tif
#
# Mapping run 245/501: basins_hydro_mc_244.tif
#
# Mapping run 246/501: basins_hydro_mc_245.tif
#
# Mapping run 247/501: basins_hydro_mc_246.tif
#
# Mapping run 248/501: basins_hydro_mc_247.tif
#
# Mapping run 249/501: basins_hydro_mc_248.tif
#
# Mapping run 250/501: basins_hydro_mc_249.tif
#
# Mapping run 251/501: basins_hydro_mc_250.tif
#
# Mapping run 252/501: basins_hydro_mc_251.tif
#
# Mapping run 253/501: basins_hydro_mc_252.tif
#
# Mapping run 254/501: basins_hydro_mc_253.tif
#
# Mapping run 255/501: basins_hydro_mc_254.tif
#
# Mapping run 256/501: basins_hydro_mc_255.tif
#
# Mapping run 257/501: basins_hydro_mc_256.tif
#
# Mapping run 258/501: basins_hydro_mc_257.tif
#
# Mapping run 259/501: basins_hydro_mc_258.tif
#
# Mapping run 260/501: basins_hydro_mc_259.tif
#
# Mapping run 261/501: basins_hydro_mc_260.tif
#
# Mapping run 262/501: basins_hydro_mc_261.tif
#
# Mapping run 263/501: basins_hydro_mc_262.tif
#
# Mapping run 264/501: basins_hydro_mc_263.tif
#
# Mapping run 265/501: basins_hydro_mc_264.tif
#
# Mapping run 266/501: basins_hydro_mc_265.tif
#
# Mapping run 267/501: basins_hydro_mc_266.tif
#
# Mapping run 268/501: basins_hydro_mc_267.tif
#
# Mapping run 269/501: basins_hydro_mc_268.tif
#
# Mapping run 270/501: basins_hydro_mc_269.tif
#
# Mapping run 271/501: basins_hydro_mc_270.tif
#
# Mapping run 272/501: basins_hydro_mc_271.tif
#
# Mapping run 273/501: basins_hydro_mc_272.tif
#
# Mapping run 274/501: basins_hydro_mc_273.tif
#
# Mapping run 275/501: basins_hydro_mc_274.tif
#
# Mapping run 276/501: basins_hydro_mc_275.tif
#
# Mapping run 277/501: basins_hydro_mc_276.tif
#
# Mapping run 278/501: basins_hydro_mc_277.tif
#
# Mapping run 279/501: basins_hydro_mc_278.tif
#
# Mapping run 280/501: basins_hydro_mc_279.tif
#
# Mapping run 281/501: basins_hydro_mc_280.tif
#
# Mapping run 282/501: basins_hydro_mc_281.tif
#
# Mapping run 283/501: basins_hydro_mc_282.tif
#
# Mapping run 284/501: basins_hydro_mc_283.tif
#
# Mapping run 285/501: basins_hydro_mc_284.tif
#
# Mapping run 286/501: basins_hydro_mc_285.tif
#
# Mapping run 287/501: basins_hydro_mc_286.tif
#
# Mapping run 288/501: basins_hydro_mc_287.tif
#
# Mapping run 289/501: basins_hydro_mc_288.tif
#
# Mapping run 290/501: basins_hydro_mc_289.tif
#
# Mapping run 291/501: basins_hydro_mc_290.tif
#
# Mapping run 292/501: basins_hydro_mc_291.tif
#
# Mapping run 293/501: basins_hydro_mc_292.tif
#
# Mapping run 294/501: basins_hydro_mc_293.tif
#
# Mapping run 295/501: basins_hydro_mc_294.tif
#
# Mapping run 296/501: basins_hydro_mc_295.tif
#
# Mapping run 297/501: basins_hydro_mc_296.tif
#
# Mapping run 298/501: basins_hydro_mc_297.tif
#
# Mapping run 299/501: basins_hydro_mc_298.tif
#
# Mapping run 300/501: basins_hydro_mc_299.tif
#
# Mapping run 301/501: basins_hydro_mc_300.tif
#
# Mapping run 302/501: basins_hydro_mc_301.tif
#
# Mapping run 303/501: basins_hydro_mc_302.tif
#
# Mapping run 304/501: basins_hydro_mc_303.tif
#
# Mapping run 305/501: basins_hydro_mc_304.tif
#
# Mapping run 306/501: basins_hydro_mc_305.tif
#
# Mapping run 307/501: basins_hydro_mc_306.tif
#
# Mapping run 308/501: basins_hydro_mc_307.tif
#
# Mapping run 309/501: basins_hydro_mc_308.tif
#
# Mapping run 310/501: basins_hydro_mc_309.tif
#
# Mapping run 311/501: basins_hydro_mc_310.tif
#
# Mapping run 312/501: basins_hydro_mc_311.tif
#
# Mapping run 313/501: basins_hydro_mc_312.tif
#
# Mapping run 314/501: basins_hydro_mc_313.tif
#
# Mapping run 315/501: basins_hydro_mc_314.tif
#
# Mapping run 316/501: basins_hydro_mc_315.tif
#
# Mapping run 317/501: basins_hydro_mc_316.tif
#
# Mapping run 318/501: basins_hydro_mc_317.tif
#
# Mapping run 319/501: basins_hydro_mc_318.tif
#
# Mapping run 320/501: basins_hydro_mc_319.tif
#
# Mapping run 321/501: basins_hydro_mc_320.tif
#
# Mapping run 322/501: basins_hydro_mc_321.tif
#
# Mapping run 323/501: basins_hydro_mc_322.tif
#
# Mapping run 324/501: basins_hydro_mc_323.tif
#
# Mapping run 325/501: basins_hydro_mc_324.tif
#
# Mapping run 326/501: basins_hydro_mc_325.tif
#
# Mapping run 327/501: basins_hydro_mc_326.tif
#
# Mapping run 328/501: basins_hydro_mc_327.tif
#
# Mapping run 329/501: basins_hydro_mc_328.tif
#
# Mapping run 330/501: basins_hydro_mc_329.tif
#
# Mapping run 331/501: basins_hydro_mc_330.tif
#
# Mapping run 332/501: basins_hydro_mc_331.tif
#
# Mapping run 333/501: basins_hydro_mc_332.tif
#
# Mapping run 334/501: basins_hydro_mc_333.tif
#
# Mapping run 335/501: basins_hydro_mc_334.tif
#
# Mapping run 336/501: basins_hydro_mc_335.tif
#
# Mapping run 337/501: basins_hydro_mc_336.tif
#
# Mapping run 338/501: basins_hydro_mc_337.tif
#
# Mapping run 339/501: basins_hydro_mc_338.tif
#
# Mapping run 340/501: basins_hydro_mc_339.tif
#
# Mapping run 341/501: basins_hydro_mc_340.tif
#
# Mapping run 342/501: basins_hydro_mc_341.tif
#
# Mapping run 343/501: basins_hydro_mc_342.tif
#
# Mapping run 344/501: basins_hydro_mc_343.tif
#
# Mapping run 345/501: basins_hydro_mc_344.tif
#
# Mapping run 346/501: basins_hydro_mc_345.tif
#
# Mapping run 347/501: basins_hydro_mc_346.tif
#
# Mapping run 348/501: basins_hydro_mc_347.tif
#
# Mapping run 349/501: basins_hydro_mc_348.tif
#
# Mapping run 350/501: basins_hydro_mc_349.tif
#
# Mapping run 351/501: basins_hydro_mc_350.tif
#
# Mapping run 352/501: basins_hydro_mc_351.tif
#
# Mapping run 353/501: basins_hydro_mc_352.tif
#
# Mapping run 354/501: basins_hydro_mc_353.tif
#
# Mapping run 355/501: basins_hydro_mc_354.tif
#
# Mapping run 356/501: basins_hydro_mc_355.tif
#
# Mapping run 357/501: basins_hydro_mc_356.tif
#
# Mapping run 358/501: basins_hydro_mc_357.tif
#
# Mapping run 359/501: basins_hydro_mc_358.tif
#
# Mapping run 360/501: basins_hydro_mc_359.tif
#
# Mapping run 361/501: basins_hydro_mc_360.tif
#
# Mapping run 362/501: basins_hydro_mc_361.tif
#
# Mapping run 363/501: basins_hydro_mc_362.tif
#
# Mapping run 364/501: basins_hydro_mc_363.tif
#
# Mapping run 365/501: basins_hydro_mc_364.tif
#
# Mapping run 366/501: basins_hydro_mc_365.tif
#
# Mapping run 367/501: basins_hydro_mc_366.tif
#
# Mapping run 368/501: basins_hydro_mc_367.tif
#
# Mapping run 369/501: basins_hydro_mc_368.tif
#
# Mapping run 370/501: basins_hydro_mc_369.tif
#
# Mapping run 371/501: basins_hydro_mc_370.tif
#
# Mapping run 372/501: basins_hydro_mc_371.tif
#
# Mapping run 373/501: basins_hydro_mc_372.tif
#
# Mapping run 374/501: basins_hydro_mc_373.tif
#
# Mapping run 375/501: basins_hydro_mc_374.tif
#
# Mapping run 376/501: basins_hydro_mc_375.tif
#
# Mapping run 377/501: basins_hydro_mc_376.tif
#
# Mapping run 378/501: basins_hydro_mc_377.tif
#
# Mapping run 379/501: basins_hydro_mc_378.tif
#
# Mapping run 380/501: basins_hydro_mc_379.tif
#
# Mapping run 381/501: basins_hydro_mc_380.tif
#
# Mapping run 382/501: basins_hydro_mc_381.tif
#
# Mapping run 383/501: basins_hydro_mc_382.tif
#
# Mapping run 384/501: basins_hydro_mc_383.tif
#
# Mapping run 385/501: basins_hydro_mc_384.tif
#
# Mapping run 386/501: basins_hydro_mc_385.tif
#
# Mapping run 387/501: basins_hydro_mc_386.tif
#
# Mapping run 388/501: basins_hydro_mc_387.tif
#
# Mapping run 389/501: basins_hydro_mc_388.tif
#
# Mapping run 390/501: basins_hydro_mc_389.tif
#
# Mapping run 391/501: basins_hydro_mc_390.tif
#
# Mapping run 392/501: basins_hydro_mc_391.tif
#
# Mapping run 393/501: basins_hydro_mc_392.tif
#
# Mapping run 394/501: basins_hydro_mc_393.tif
#
# Mapping run 395/501: basins_hydro_mc_394.tif
#
# Mapping run 396/501: basins_hydro_mc_395.tif
#
# Mapping run 397/501: basins_hydro_mc_396.tif
#
# Mapping run 398/501: basins_hydro_mc_397.tif
#
# Mapping run 399/501: basins_hydro_mc_398.tif
#
# Mapping run 400/501: basins_hydro_mc_399.tif
#
# Mapping run 401/501: basins_hydro_mc_400.tif
#
# Mapping run 402/501: basins_hydro_mc_401.tif
#
# Mapping run 403/501: basins_hydro_mc_402.tif
#
# Mapping run 404/501: basins_hydro_mc_403.tif
#
# Mapping run 405/501: basins_hydro_mc_404.tif
#
# Mapping run 406/501: basins_hydro_mc_405.tif
#
# Mapping run 407/501: basins_hydro_mc_406.tif
#
# Mapping run 408/501: basins_hydro_mc_407.tif
#
# Mapping run 409/501: basins_hydro_mc_408.tif
#
# Mapping run 410/501: basins_hydro_mc_409.tif
#
# Mapping run 411/501: basins_hydro_mc_410.tif
#
# Mapping run 412/501: basins_hydro_mc_411.tif
#
# Mapping run 413/501: basins_hydro_mc_412.tif
#
# Mapping run 414/501: basins_hydro_mc_413.tif
#
# Mapping run 415/501: basins_hydro_mc_414.tif
#
# Mapping run 416/501: basins_hydro_mc_415.tif
#
# Mapping run 417/501: basins_hydro_mc_416.tif
#
# Mapping run 418/501: basins_hydro_mc_417.tif
#
# Mapping run 419/501: basins_hydro_mc_418.tif
#
# Mapping run 420/501: basins_hydro_mc_419.tif
#
# Mapping run 421/501: basins_hydro_mc_420.tif
#
# Mapping run 422/501: basins_hydro_mc_421.tif
#
# Mapping run 423/501: basins_hydro_mc_422.tif
#
# Mapping run 424/501: basins_hydro_mc_423.tif
#
# Mapping run 425/501: basins_hydro_mc_424.tif
#
# Mapping run 426/501: basins_hydro_mc_425.tif
#
# Mapping run 427/501: basins_hydro_mc_426.tif
#
# Mapping run 428/501: basins_hydro_mc_427.tif
#
# Mapping run 429/501: basins_hydro_mc_428.tif
#
# Mapping run 430/501: basins_hydro_mc_429.tif
#
# Mapping run 431/501: basins_hydro_mc_430.tif
#
# Mapping run 432/501: basins_hydro_mc_431.tif
#
# Mapping run 433/501: basins_hydro_mc_432.tif
#
# Mapping run 434/501: basins_hydro_mc_433.tif
#
# Mapping run 435/501: basins_hydro_mc_434.tif
#
# Mapping run 436/501: basins_hydro_mc_435.tif
#
# Mapping run 437/501: basins_hydro_mc_436.tif
#
# Mapping run 438/501: basins_hydro_mc_437.tif
#
# Mapping run 439/501: basins_hydro_mc_438.tif
#
# Mapping run 440/501: basins_hydro_mc_439.tif
#
# Mapping run 441/501: basins_hydro_mc_440.tif
#
# Mapping run 442/501: basins_hydro_mc_441.tif
#
# Mapping run 443/501: basins_hydro_mc_442.tif
#
# Mapping run 444/501: basins_hydro_mc_443.tif
#
# Mapping run 445/501: basins_hydro_mc_444.tif
#
# Mapping run 446/501: basins_hydro_mc_445.tif
#
# Mapping run 447/501: basins_hydro_mc_446.tif
#
# Mapping run 448/501: basins_hydro_mc_447.tif
#
# Mapping run 449/501: basins_hydro_mc_448.tif
#
# Mapping run 450/501: basins_hydro_mc_449.tif
#
# Mapping run 451/501: basins_hydro_mc_450.tif
#
# Mapping run 452/501: basins_hydro_mc_451.tif
#
# Mapping run 453/501: basins_hydro_mc_452.tif
#
# Mapping run 454/501: basins_hydro_mc_453.tif
#
# Mapping run 455/501: basins_hydro_mc_454.tif
#
# Mapping run 456/501: basins_hydro_mc_455.tif
#
# Mapping run 457/501: basins_hydro_mc_456.tif
#
# Mapping run 458/501: basins_hydro_mc_457.tif
#
# Mapping run 459/501: basins_hydro_mc_458.tif
#
# Mapping run 460/501: basins_hydro_mc_459.tif
#
# Mapping run 461/501: basins_hydro_mc_460.tif
#
# Mapping run 462/501: basins_hydro_mc_461.tif
#
# Mapping run 463/501: basins_hydro_mc_462.tif
#
# Mapping run 464/501: basins_hydro_mc_463.tif
#
# Mapping run 465/501: basins_hydro_mc_464.tif
#
# Mapping run 466/501: basins_hydro_mc_465.tif
#
# Mapping run 467/501: basins_hydro_mc_466.tif
#
# Mapping run 468/501: basins_hydro_mc_467.tif
#
# Mapping run 469/501: basins_hydro_mc_468.tif
#
# Mapping run 470/501: basins_hydro_mc_469.tif
#
# Mapping run 471/501: basins_hydro_mc_470.tif
#
# Mapping run 472/501: basins_hydro_mc_471.tif
#
# Mapping run 473/501: basins_hydro_mc_472.tif
#
# Mapping run 474/501: basins_hydro_mc_473.tif
#
# Mapping run 475/501: basins_hydro_mc_474.tif
#
# Mapping run 476/501: basins_hydro_mc_475.tif
#
# Mapping run 477/501: basins_hydro_mc_476.tif
#
# Mapping run 478/501: basins_hydro_mc_477.tif
#
# Mapping run 479/501: basins_hydro_mc_478.tif
#
# Mapping run 480/501: basins_hydro_mc_479.tif
#
# Mapping run 481/501: basins_hydro_mc_480.tif
#
# Mapping run 482/501: basins_hydro_mc_481.tif
#
# Mapping run 483/501: basins_hydro_mc_482.tif
#
# Mapping run 484/501: basins_hydro_mc_483.tif
#
# Mapping run 485/501: basins_hydro_mc_484.tif
#
# Mapping run 486/501: basins_hydro_mc_485.tif
#
# Mapping run 487/501: basins_hydro_mc_486.tif
#
# Mapping run 488/501: basins_hydro_mc_487.tif
#
# Mapping run 489/501: basins_hydro_mc_488.tif
#
# Mapping run 490/501: basins_hydro_mc_489.tif
#
# Mapping run 491/501: basins_hydro_mc_490.tif
#
# Mapping run 492/501: basins_hydro_mc_491.tif
#
# Mapping run 493/501: basins_hydro_mc_492.tif
#
# Mapping run 494/501: basins_hydro_mc_493.tif
#
# Mapping run 495/501: basins_hydro_mc_494.tif
#
# Mapping run 496/501: basins_hydro_mc_495.tif
#
# Mapping run 497/501: basins_hydro_mc_496.tif
#
# Mapping run 498/501: basins_hydro_mc_497.tif
#
# Mapping run 499/501: basins_hydro_mc_498.tif
#
# Mapping run 500/501: basins_hydro_mc_499.tif
#
# Mapping run 501/501: basins_hydro_mc_500.tif
#
# ✓ Finished building label mappings to reference basins
# [Pass] Rows 0–31
# [Pass] Rows 32–63
# [Pass] Rows 64–95
# [Pass] Rows 96–127
# [Pass] Rows 128–159
# [Pass] Rows 160–191
# [Pass] Rows 192–223
# [Pass] Rows 224–255
# [Pass] Rows 256–287
# [Pass] Rows 288–319
# [Pass] Rows 320–351
# [Pass] Rows 352–383
# [Pass] Rows 384–415
# [Pass] Rows 416–447
# [Pass] Rows 448–479
# [Pass] Rows 480–511
# [Pass] Rows 512–543
# [Pass] Rows 544–575
# [Pass] Rows 576–607
# [Pass] Rows 608–639
# [Pass] Rows 640–671
# [Pass] Rows 672–703
# [Pass] Rows 704–735
# [Pass] Rows 736–767
# [Pass] Rows 768–799
# [Pass] Rows 800–831
# [Pass] Rows 832–863
# [Pass] Rows 864–895
# [Pass] Rows 896–927
# [Pass] Rows 928–959
# [Pass] Rows 960–991
# [Pass] Rows 992–1023
# [Pass] Rows 1024–1055
# [Pass] Rows 1056–1087
# [Pass] Rows 1088–1119
# [Pass] Rows 1120–1151
# [Pass] Rows 1152–1183
# [Pass] Rows 1184–1215
# [Pass] Rows 1216–1247
# [Pass] Rows 1248–1279
# [Pass] Rows 1280–1311
# [Pass] Rows 1312–1343
# [Pass] Rows 1344–1375
# [Pass] Rows 1376–1407
# [Pass] Rows 1408–1439
# [Pass] Rows 1440–1471
# [Pass] Rows 1472–1503
# [Pass] Rows 1504–1535
# [Pass] Rows 1536–1567
# [Pass] Rows 1568–1599
# [Pass] Rows 1600–1631
# [Pass] Rows 1632–1663
# [Pass] Rows 1664–1695
# [Pass] Rows 1696–1727
# [Pass] Rows 1728–1759
# [Pass] Rows 1760–1791
# [Pass] Rows 1792–1823
# [Pass] Rows 1824–1855
# [Pass] Rows 1856–1887
# [Pass] Rows 1888–1919
# [Pass] Rows 1920–1951
# [Pass] Rows 1952–1983
# [Pass] Rows 1984–2015
# [Pass] Rows 2016–2047
# [Pass] Rows 2048–2079
# [Pass] Rows 2080–2111
# [Pass] Rows 2112–2143
# [Pass] Rows 2144–2175
# [Pass] Rows 2176–2207
# [Pass] Rows 2208–2239
# [Pass] Rows 2240–2271
# [Pass] Rows 2272–2303
# [Pass] Rows 2304–2335
# [Pass] Rows 2336–2367
# [Pass] Rows 2368–2399
# [Pass] Rows 2400–2431
# [Pass] Rows 2432–2463
# [Pass] Rows 2464–2495
# [Pass] Rows 2496–2527
# [Pass] Rows 2528–2559
# [Pass] Rows 2560–2591
# [Pass] Rows 2592–2623
# [Pass] Rows 2624–2655
# [Pass] Rows 2656–2687
# [Pass] Rows 2688–2719
# [Pass] Rows 2720–2751
# [Pass] Rows 2752–2783
# [Pass] Rows 2784–2815
# [Pass] Rows 2816–2847
# [Pass] Rows 2848–2879
# [Pass] Rows 2880–2911
# [Pass] Rows 2912–2943
# [Pass] Rows 2944–2975
# [Pass] Rows 2976–3007
# [Pass] Rows 3008–3039
# [Pass] Rows 3040–3071
# [Pass] Rows 3072–3103
# [Pass] Rows 3104–3135
# [Pass] Rows 3136–3167
# [Pass] Rows 3168–3199
# [Pass] Rows 3200–3231
# [Pass] Rows 3232–3263
# [Pass] Rows 3264–3295
# [Pass] Rows 3296–3327
# [Pass] Rows 3328–3359
# [Pass] Rows 3360–3391
# [Pass] Rows 3392–3423
# [Pass] Rows 3424–3455
# [Pass] Rows 3456–3487
# [Pass] Rows 3488–3519
# [Pass] Rows 3520–3551
# [Pass] Rows 3552–3583
# [Pass] Rows 3584–3615
# [Pass] Rows 3616–3647
# [Pass] Rows 3648–3679
# [Pass] Rows 3680–3711
# [Pass] Rows 3712–3743
# [Pass] Rows 3744–3775
# [Pass] Rows 3776–3807
# [Pass] Rows 3808–3839
# [Pass] Rows 3840–3871
# [Pass] Rows 3872–3903
# [Pass] Rows 3904–3935
# [Pass] Rows 3936–3967
# [Pass] Rows 3968–3999
# [Pass] Rows 4000–4031
# [Pass] Rows 4032–4063
# [Pass] Rows 4064–4095
# [Pass] Rows 4096–4127
# [Pass] Rows 4128–4159
# [Pass] Rows 4160–4191
# [Pass] Rows 4192–4223
# [Pass] Rows 4224–4255
# [Pass] Rows 4256–4287
# [Pass] Rows 4288–4319
# [Pass] Rows 4320–4351
# [Pass] Rows 4352–4383
# [Pass] Rows 4384–4415
# [Pass] Rows 4416–4447
# [Pass] Rows 4448–4479
# [Pass] Rows 4480–4511
# [Pass] Rows 4512–4543
# [Pass] Rows 4544–4575
# [Pass] Rows 4576–4607
# [Pass] Rows 4608–4639
# [Pass] Rows 4640–4671
# [Pass] Rows 4672–4703
# [Pass] Rows 4704–4735
# [Pass] Rows 4736–4767
# [Pass] Rows 4768–4799
# [Pass] Rows 4800–4831
# [Pass] Rows 4832–4863
# [Pass] Rows 4864–4895
# [Pass] Rows 4896–4927
# [Pass] Rows 4928–4959
# [Pass] Rows 4960–4991
# [Pass] Rows 4992–5023
# [Pass] Rows 5024–5035
# ✓ Wrote basins_most_likely, basins_certainty, basin_boundary_probability
# ✓ Wrote basins_uncertainty: basins_uncertainty2.tif
# ✓ Wrote stable and uncertain divide masks
# Done.

# %%
gs.run_command("g.remove", flags="f", type="raster", name="tmp1,tmp2")
# or using pattern
gs.run_command("g.remove", flags="f", type="raster", pattern="tmp_*")
# Out:
# No file(s) found for type(s): raster
# No file(s) found for type(s): raster
